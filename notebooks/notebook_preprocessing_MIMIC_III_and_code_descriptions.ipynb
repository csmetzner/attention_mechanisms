# %% [markdown]
# # Notebook for Preprocessing of Raw Data
#
# This notebook handles the preprocessing of the raw clinical notes of the MIMIC-III dataset. MIMIC-III is a publicly, available dataset containing data on over 40,000 ICU-patients retrieved from https://physionet.org/content/mimiciii/1.4/.
#
# This notebook creates to subsets of MIMIC-III
# - MIMIC-III-Full: Contains hospital discharge summary notes associated with 52,722 unique identifiers and has a label space of 8,907 labels
# - MIMIC-III-50: Contains hospital discharge summary notes associated with 11,368 unique identifiers with the 50 most frequent labels.
#
# For the purpose of reproducibility we utilize existing information about the splits (i.e., training, validation, testing - https://github.com/jamesmullenbach/caml-mimic/tree/master/mimicdata/mimic3)  and the selection of the 50 most-frequent labels (https://github.com/jamesmullenbach/caml-mimic/blob/master/notebooks/dataproc_mimic_III.ipynb).
#
#
# Click *Cell* --> *Run All* to execute preprocessing of the clinical documents.
#
# This may take some time.
#
# This notebook automatically runs the notebook with the name **notebook_preprocessing_icd9_code_descriptions** controlling the preprocessing of the ICD-9 code descriptions.

# %% [markdown]
# # Load Libraries

# %%
# Built-in libraries
import os
import sys
import pickle
from typing import List
import re



# Set root path - it is expected to have the raw data stored in the following structure
# /root/data/raw/NOTESEVENTS.csv
# The processed data are saved to the following location
# /root/data/processed/Data.pkl
try:
    root = os.path.dirname(os.path.dirname(oa.path.abspath(__file__)))
except NameError:
    root = os.path.dirname(os.getcwd())
sys.path.append(root)

# Installed libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from torchtext.vocab import build_vocab_from_iterator
from gensim.models import Word2Vec
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from gensim.test.utils import common_texts
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

# custom libraries
from src.tools.utils_preprocess import rel2abs, preproc_clinical_notes
from src.tools.utils_preprocess import create_splits, get_class_type
# Out:
# [nltk_data] Downloading package punkt to /Users/cmetzner/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/cmetzner/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/cmetzner/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
subsets = ['MimicFull', 'Mimic50']
# Set variables
SEED = 42

# Change paths to location of raw data (PROCEDURES_ICD.csv and DIAGNOSES_ICD.csv)
path_data_raw = os.path.join(root, 'data', 'raw')
# Change paths to location of processed data
path_data_proc = os.path.join(root, 'data', 'processed')
# Change paths to location where code descriptions are stored (CMS32_DESC_LONG_SHORT_DX.xlsx and CMS32_DESC_LONG_SHORT_SG.xlsx)
path_data_external = os.path.join(root, 'data', 'external')


# Create directories to store dataset specific data
for subset in subsets:
    if not os.path.exists(os.path.join(path_data_proc, f'data_{subset}/')):
        os.makedirs(os.path.join(path_data_proc, f'data_{subset}/'))

# %% [markdown]
# # Preprocess ICD-9 Procedure/Diagnoses Codes

# %%
# Load ICD-9 procedure and diagnosis codes
df_proc = pd.read_csv(os.path.join(path_data_raw, 'PROCEDURES_ICD.csv'))
df_diag = pd.read_csv(os.path.join(path_data_raw, 'DIAGNOSES_ICD.csv'))

# Remove all rows that have no ICD9-codes
df_proc = df_proc[~df_proc['ICD9_CODE'].isna()]
df_diag = df_diag[~df_diag['ICD9_CODE'].isna()]

print('PROCEDURE CODES:')
print(f'Shape of procedure data: {df_proc.shape}')
print(f"Number of unique patient ids (SUBJECT_ID): {df_proc.SUBJECT_ID.nunique()}")
print(f"Number of unique hospital admission ids (HADM_ID): {df_proc.HADM_ID.nunique()}")
print(f"Number of unique ICD-9 procedure codes: {df_proc.ICD9_CODE.nunique()}")
print()
print('DIAGNOSES CODES:')
print(f'Shape of diagnosis data: {df_diag.shape}')
print(f"Number of unique patient ids (SUBJECT_ID): {df_diag.SUBJECT_ID.nunique()}")
print(f"Number of unique hospital admission ids (HADM_ID): {df_diag.HADM_ID.nunique()}")
print(f"Number of unique ICD-9 diagnosis codes: {df_diag.ICD9_CODE.nunique()}")

print(f'\nTotal number of ICD-9 codes in raw data of MIMIC-III: {df_proc.ICD9_CODE.nunique() + df_diag.ICD9_CODE.nunique()}')
# Out:
# PROCEDURE CODES:
# Shape of procedure data: (240095, 5)
# Number of unique patient ids (SUBJECT_ID): 42214
# Number of unique hospital admission ids (HADM_ID): 52243
# Number of unique ICD-9 procedure codes: 2009
#
# DIAGNOSES CODES:
# Shape of diagnosis data: (651000, 5)
# Number of unique patient ids (SUBJECT_ID): 46517
# Number of unique hospital admission ids (HADM_ID): 58929
# Number of unique ICD-9 diagnosis codes: 6984
#
# Total number of ICD-9 codes in raw data of MIMIC-III: 8993

# %%
# Set ICD-9 codes to strings
df_proc['ICD9_CODE'] = df_proc['ICD9_CODE'].astype(str)
df_diag['ICD9_CODE'] = df_diag['ICD9_CODE'].astype(str)

# Remove all whitespace
df_proc['ICD9_CODE'] = df_proc.apply(lambda x: x.ICD9_CODE.strip(), axis=1)
df_diag['ICD9_CODE'] = df_diag.apply(lambda x: x.ICD9_CODE.strip(), axis=1)

# Transform ICD-9 code from relative to absolute represenation
df_proc['ABS_CODE'] = df_proc.apply(lambda x: rel2abs(x.ICD9_CODE, flag_proc=True), axis=1)
df_diag['ABS_CODE'] = df_diag.apply(lambda x: rel2abs(x.ICD9_CODE, flag_proc=False), axis=1)

# Add column to dataframe indicating type of ICD-9 code
df_proc['ICD9_TYPE'] = 'procedure'
df_diag['ICD9_TYPE'] = 'diagnosis'

# Concat dataframes containing procedure and diagnosis codes
df_codes = pd.concat([df_diag, df_proc])

# Show final df_codes
display(df_codes.head(3))

# Save codes as csv file at /root/data/processed/ALL_CODES.csv
df_codes.to_csv(os.path.join(path_data_proc, 'ALL_CODES.csv'), index=False,
                columns=['SUBJECT_ID', 'HADM_ID', 'ABS_CODE', 'ICD9_TYPE'],
                header=['SUBJECT_ID', 'HADM_ID', 'ICD9_CODE', 'ICD9_TYPE'])
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE ABS_CODE  ICD9_TYPE
# 0    1297         109   172335      1.0     40301   403.01  diagnosis
# 1    1298         109   172335      2.0       486      486  diagnosis
# 2    1299         109   172335      3.0     58281   582.81  diagnosis

# %%
# Load clinical notes dataset
notes = pd.read_csv(os.path.join(path_data_raw, 'NOTEEVENTS.csv'))

# We only consider notes of the category 'Discharge Summary'; these notes can include potential addenda
notes = notes.loc[notes.CATEGORY == 'Discharge summary']
notes = notes[['SUBJECT_ID', 'HADM_ID', 'TEXT']]

# %%
# Stores preprocessed clinical notes at /root/data/processed/CLEANED_NOTES.pkl
notes = preproc_clinical_notes(df_notes=notes,
                               path_data_proc=path_data_proc)
# Out:
#   0%|          | 0/52726 [00:00<?, ?it/s]
#   0%|          | 0/52726 [00:00<?, ?it/s]

# %%
notes.head(3)
# Out:
#    SUBJECT_ID   HADM_ID                                               TEXT  \
# 0       22532  167853.0  admission date : deidentified discharge date :...
# 1       13702  107527.0  admission date : deidentified discharge date :...
# 2       13702  167118.0  admission date : deidentified discharge date :...
#
#                                               TOKENS
# 0  [admission, date, :, deidentified, discharge, ...
# 1  [admission, date, :, deidentified, discharge, ...
# 2  [admission, date, :, deidentified, discharge, ...

# %% [markdown]
# # Combine cleaned Notes and ICD-9 Labels
#
# This section combines the cleaned clinical notes (i.e., hospital discharge summaries) and the ICD-9 procedure and diagnoses codes on unique hospital admission ids.

# %%
notes = pd.read_pickle(os.path.join(path_data_proc, 'CLEANED_NOTES.pkl'))
notes.head(3)
# Out:
#    SUBJECT_ID   HADM_ID                                               TEXT  \
# 0       22532  167853.0  admission date : deidentified discharge date :...
# 1       13702  107527.0  admission date : deidentified discharge date :...
# 2       13702  167118.0  admission date : deidentified discharge date :...
#
#                                               TOKENS
# 0  [admission, date, :, deidentified, discharge, ...
# 1  [admission, date, :, deidentified, discharge, ...
# 2  [admission, date, :, deidentified, discharge, ...

# %%
codes = pd.read_csv(os.path.join(path_data_proc, 'ALL_CODES.csv'), dtype={'ICD9_CODE': str})
codes.head(3)
# Out:
#    SUBJECT_ID  HADM_ID ICD9_CODE  ICD9_TYPE
# 0         109   172335    403.01  diagnosis
# 1         109   172335       486  diagnosis
# 2         109   172335    582.81  diagnosis

# %%
# 1. Align HADM_IDS of codes and notes
# Some HADM_ID have no codes but no notes
# Some HADM_ID have notes but no codes (we already filtered out the HADM_ID without codes)

# Get all hospital admission ids that have notes
hadm_notes = notes.HADM_ID.unique().tolist()

# Retrieve codes for those hospital admission ids
codes = codes[codes['HADM_ID'].isin(hadm_notes)]

# Number of hospital admissions with clinical notes
print(f'Number of hospital admission ids with clinical notes: {notes.shape[0]}')

# Check number of hospital admission id's in codes dataset
print(f'Number of hospital admission ids that have codes and notes: {codes.HADM_ID.nunique()}')

# Apparently, we have 4 hospital admission id's that have notes but no codes
# Let's filter them out.
# Get hospital admission ids with notes but are not included in the codes dataframe
display(notes[~notes['HADM_ID'].isin(codes.HADM_ID.unique().tolist())])

hadm_notes_wo_codes = notes[~notes['HADM_ID'].isin(codes.HADM_ID.unique().tolist())].HADM_ID.tolist()
print(hadm_notes_wo_codes)
# Out:
# Number of hospital admission ids with clinical notes: 52726
# Number of hospital admission ids that have codes and notes: 52722
#        SUBJECT_ID   HADM_ID  \
# 16238       13567  110220.0
# 21393       31866  182252.0
# 23115       24975  109963.0
# 32306       17796  142890.0
#
#                                                     TEXT  \
# 16238  admission date : deidentified discharge date :...
# 21393  admission date : deidentified discharge date :...
# 23115  admission date : deidentified discharge date :...
# 32306  admission date : deidentified discharge date :...
#
#                                                   TOKENS
# 16238  [admission, date, :, deidentified, discharge, ...
# 21393  [admission, date, :, deidentified, discharge, ...
# 23115  [admission, date, :, deidentified, discharge, ...
# 32306  [admission, date, :, deidentified, discharge, ...
# [110220.0, 182252.0, 109963.0, 142890.0]

# %%
notes = notes[~notes['HADM_ID'].isin(hadm_notes_wo_codes)]

# %%
# 1. Check if both dataframes have same number of hospital admission id's
print('Check if number of HADM_IDs are equal in both dataframes.')
print(f'Codes == Notes : {codes.HADM_ID.nunique()} == {notes.HADM_ID.nunique()}')
# Out:
# Check if number of HADM_IDs are equal in both dataframes.
# Codes == Notes : 52722 == 52722

# %% [markdown]
# # Create MIMIC-III-Full and MIMIC-III-50 Subsets

# %%
def get_label_frequency_stats(df_codes: pd.DataFrame,
                              dataset: str,
                             labels: List[str]) -> None:
    
    label_counts = df_codes.ICD9_CODE.value_counts()
    arr= label_counts.values
    # Get percentiles at 25, 50, and 75
    q25 = np.quantile(arr, 0.25)
    q50 = np.quantile(arr, 0.5)
    q75 = np.quantile(arr, 0.75)
    
    print(f'Q1: {q25}')
    print(f'Median: {q50}')
    print(f'Q3: {q75}')
    
    # Create dictionary for storing the labels' affiliation to a certain quartile (Q1, Q2, Q3, or Q4)
    _d = {}
    
    for label, value in label_counts.items():
        _d[label] = {'freq': value}
        if value >= q75:
            _d[label]['quartile'] = 3  # (Q3, +inf)
        elif q50 <= value < q75:
            _d[label]['quartile'] = 2  # (Q2, Q3)
        elif q25 <= value < q50:
            _d[label]['quartile'] = 1  # (Q1, Q2)
        else:
            _d[label]['quartile'] = 0  # (-inf, Q1)
            
    l_codes_quartiles = []
    for label in labels:
        l_codes_quartiles.append(_d[label]["quartile"])
        
        
    with open(os.path.join(path_data_proc, f'data_{dataset}', f'l_codes_quartiles_{dataset}.pkl'), 'wb') as f:
        pickle.dump(l_codes_quartiles, f)

    with open(os.path.join(path_data_proc, f'data_{dataset}', f'l_codes_dict_{dataset}.pkl'), 'wb') as f:
        pickle.dump(_d, f)

# %% [markdown]
# ## MIMIC-III-Full

# %% [markdown]
# ## Dataset: 'full' set of codes in MIMIC-III:

# %%
codes_full = codes.copy()
# Get list of unique labels 
l_codes_full = sorted(codes_full.ICD9_CODE.unique().tolist())
print(f'Number of billable code labels: {len(l_codes_full)}')
with open(os.path.join(path_data_proc, f'data_MimicFull', 'l_codes_MimicFull.pkl'), 'wb') as f:
    pickle.dump(l_codes_full, f)

# Aggregate individual label mentions in lists
codes_full = codes_full.groupby(['SUBJECT_ID', 'HADM_ID']).agg({'ICD9_CODE': list}).reset_index()

# Remove redundant labels in lists
codes_full['ICD9_CODE'] = codes_full.apply(lambda x: sorted(list(set(x.ICD9_CODE))), axis=1)

# Generate full dataset
df_full = codes_full.merge(notes, how='left', on=['SUBJECT_ID', 'HADM_ID']).sort_values(['SUBJECT_ID', 'HADM_ID'])

# Save dataset
df_full.to_pickle(os.path.join(path_data_proc, 'data_MimicFull', 'DATA_MimicFull.pkl'))
# Out:
# Number of billable code labels: 8907

# %%
MIN_FREQ = 3
create_splits(subset='MimicFull', path_data_proc=path_data_proc, min_freq=MIN_FREQ)
# Out:
# Current subset: MimicFull
# Current split: train
# Vocab size for train: 120481
# Current split: test
# Current split: val

# %%
# Get statistics for MIMIC-III-50
hadm_ids = []
print('Data Description for MIMIC-III-Full')
for split in ['train', 'val', 'test']:
    print(f'Description for {split} split:')
    split_ids = pd.read_csv(os.path.join(path_data_proc, f'data_MimicFull', f'ids_MimicFull_{split}.csv')).HADM_ID.tolist()
    hadm_ids += split_ids
    
    df_full_split = df_full[df_full['HADM_ID'].isin(split_ids)]
    print(f'Number of unique patient ids: {df_full_split.SUBJECT_ID.nunique()}')
    print(f'Number of unique hospital admission ids in {split} dataset: {len(split_ids)}')
    

df_full = df_full[df_full['HADM_ID'].isin(hadm_ids)]
df_full_codes = df_full.explode('ICD9_CODE')
print(f'Number of unique codes: {len(df_full_codes.ICD9_CODE.unique())}')
print()
df_full['avg_words_doc'] = df_full.apply(lambda x: len(x.TOKENS), axis=1)
avg_words_docs = np.mean(df_full['avg_words_doc'])
std_words_docs = np.std(df_full['avg_words_doc'])
df_full['avg_labels_doc'] = df_full.apply(lambda x: len(x.ICD9_CODE), axis=1)
avg_labels_doc = np.mean(df_full['avg_labels_doc'])
print(f'Average Number of Words per Document: {avg_words_docs}')
print(f'Std of Words per Document: {std_words_docs}')
print(f'Average Number of Labels per Document: {avg_labels_doc}')

# Get frequency and quartile
print()
get_label_frequency_stats(df_full_codes, dataset='MimicFull', labels=l_codes_full)
# Out:
# Data Description for MIMIC-III-Full
# Description for train split:
# Number of unique patient ids: 36997
# Number of unique hospital admission ids in train dataset: 47719
# Description for val split:
# Number of unique patient ids: 1374
# Number of unique hospital admission ids in val dataset: 1631
# Description for test split:
# Number of unique patient ids: 2755
# Number of unique hospital admission ids in test dataset: 3372
# Number of unique codes: 8907
#
# Average Number of Words per Document: 1861.5246766055916
# Std of Words per Document: 948.6767511098549
# Average Number of Labels per Document: 15.8828193164144
#
# Q1: 2.0
# Median: 6.0
# Q3: 28.0

# %% [markdown]
# ## MIMIC-III-50

# %%
# MIMIC-III-50: 50-most-frequent codes retrieved from https://github.com/jamesmullenbach/caml-mimic/blob/master/notebooks/dataproc_mimic_III.ipynb
l_codes_50 = ['038.9',
 '244.9',
 '250.00',
 '272.0',
 '272.4',
 '276.1',
 '276.2',
 '285.1',
 '285.9',
 '287.5',
 '305.1',
 '311',
 '33.24',
 '36.15',
 '37.22',
 '38.91',
 '38.93',
 '39.61',
 '39.95',
 '401.9',
 '403.90',
 '410.71',
 '412',
 '414.01',
 '424.0',
 '427.31',
 '428.0',
 '45.13',
 '486',
 '496',
 '507.0',
 '511.9',
 '518.81',
 '530.81',
 '584.9',
 '585.9',
 '599.0',
 '88.56',
 '88.72',
 '93.90',
 '96.04',
 '96.6',
 '96.71',
 '96.72',
 '99.04',
 '99.15',
 '995.92',
 'V15.82',
 'V45.81',
 'V58.61']

# Save
with open(os.path.join(path_data_proc, 'data_Mimic50', 'l_codes_Mimic50.pkl'), 'wb') as f:
    pickle.dump(l_codes_50, f)

# %%
codes_50 = codes.copy()
codes_50 = codes_50[codes_50['ICD9_CODE'].isin(l_codes_50)]

# Aggregate individual label mentions in lists
codes_50 = codes_50.groupby(['SUBJECT_ID', 'HADM_ID']).agg({'ICD9_CODE': list}).reset_index()

# Remove redundant labels in lists
codes_50['ICD9_CODE'] = codes_50.apply(lambda x: sorted(list(set(x.ICD9_CODE))), axis=1)

# Generate full dataset
df_50 = codes_50.merge(notes, how='left', on=['SUBJECT_ID', 'HADM_ID']).sort_values(['SUBJECT_ID', 'HADM_ID'])

# Save dataset
df_50.to_pickle(os.path.join(path_data_proc, 'data_Mimic50', 'DATA_Mimic50.pkl'))

# %%
MIN_FREQ = 3

create_splits(subset='Mimic50', path_data_proc=path_data_proc, min_freq=MIN_FREQ)
# Out:
# Current subset: Mimic50
# Current split: train
# Vocab size for train: 50176
# Current split: test
# Current split: val

# %%
# Get statistics for MIMIC-III-50
hadm_ids = []
print('Data Description for MIMIC-III-50')
for split in ['train', 'val', 'test']:
    print(f'Description for {split} split:')
    split_ids = pd.read_csv(os.path.join(path_data_proc, f'data_Mimic50', f'ids_Mimic50_{split}.csv')).HADM_ID.tolist()
    hadm_ids += split_ids
    
    df50_split = df_50[df_50['HADM_ID'].isin(split_ids)]
    print(f'Number of unique patient ids: {df50_split.SUBJECT_ID.nunique()}')
    print(f'Number of unique hospital admission ids in {split} dataset: {len(split_ids)}')
    

df50 = df_50[df_50['HADM_ID'].isin(hadm_ids)]
df_50_codes = df50.explode('ICD9_CODE')
print(f'Number of unique codes: {len(df_50_codes.ICD9_CODE.unique())}')
print()
df50['avg_words_doc'] = df50.apply(lambda x: len(x.TOKENS), axis=1)
avg_words_docs = np.mean(df50['avg_words_doc'])
std_words_docs = np.std(df50['avg_words_doc'])
df50['avg_labels_doc'] = df50.apply(lambda x: len(x.ICD9_CODE), axis=1)
avg_labels_doc = np.mean(df50['avg_labels_doc'])
print(f'Average Number of Words per Document: {avg_words_docs}')
print(f'Std of Words per Document: {std_words_docs}')
print(f'Average Number of Labels per Document: {avg_labels_doc}')

# Get frequency and quartile
print()
get_label_frequency_stats(df_50_codes, dataset='Mimic50', labels=l_codes_50)
# Out:
# Data Description for MIMIC-III-50
# Description for train split:
# Number of unique patient ids: 7501
# Number of unique hospital admission ids in train dataset: 8066
# Description for val split:
# Number of unique patient ids: 1329
# Number of unique hospital admission ids in val dataset: 1573
# Description for test split:
# Number of unique patient ids: 1526
# Number of unique hospital admission ids in test dataset: 1729
# Number of unique codes: 50
#
# Average Number of Words per Document: 1989.295830401126
# Std of Words per Document: 968.2481012006912
# Average Number of Labels per Document: 5.770496129486277
#
# Q1: 751.75
# Median: 1021.0
# Q3: 1531.5

# %% [markdown]
# # Preprocessing of Raw ICD-9 Code Descriptions
#
# This notebook handles the preprocessing of the raw ICD-9 Code Descriptions related to the MIMIC-III dataset. The descriptions were taken from https://physionet.org/content/mimiciii/1.4/.
#
# Click *Cell* --> *Run Cells* to retrieve code description embeddings

# %% [markdown]
# # Processing ICD-9 Codes

# %%
# Custom libraries
def rel2abs(x: str, flag_proc: bool = True) -> str:
    """ Function that transform relative ICD-9 code into absolute code

    Parameters
    ----------
    x : str
        relative ICD-9 code
    flag_proc : bool; default=True
        flag indicating if relative code is a procedure or diagnosis code

    Returns
    -------
    str
        absolute ICD-9 code, e.g., procedure: XX.XX / diagnosis: XXX.XX

    """
    if flag_proc:
        # Some codes are billable with only two or three digits, do not add period
        if len(x) == 2:  # Procedure codes
            return x
        else:
            return f'{x[:2]}.{x[2:]}'
    else:
        if len(x) == 3:  # Diagnosis codes
            return x
        else:
            if x[0] == 'E':
                if len(x) == 4:
                    return x
                else:
                    return f'{x[:4]}.{x[4:]}'
            else:
                return f'{x[:3]}.{x[3:]}'
            
            
def clean_desc(text: str) -> List[str]:
    """
    Function that preprocesses the text code/category descriptions by cleaning, tokenizing, and removing
    english stopwords.
    This function requires to have the following "nltk" packages installed:
        - nltk.download('punkt')
        - nltk.download('stopwords')
    
    Parameter
    ----------
    text : str
        Input code descriptions
    
    Return
    ------
    List[str]
        Preprocessed tokens for respective code description.
        
    """
    
    # 1. Transform text to be lowercase
    text = text.lower()
    # 2. Replace all newline characters to be spaces
    text = text.replace('\n', ' ')
    # 3. Remove excessive whitespace
    text = re.sub(' +', ' ', text)  
    # 4. Remove punctuations from string
    punc = ['.', '?', '!', ',', '#', ':', ';', '(', ')', '%', '/', '-', '+', '=', '&', '_']
    for p in punc:
        text = re.sub('\%s' % p, '', text)
    # 5. Tokenize string
    tokens = word_tokenize(text)
    # 6. Remove stopwords
    tokens = [word for word in tokens if not word in stopwords.words()]
    return tokens

# %% [markdown]
# # Preprocess ICD-9 Procedure and Diagnosis Code Descriptions

# %%
# DIAGNOSES CODES
diag_desc = pd.read_csv(os.path.join(root, 'data', 'external', 'D_ICD_DIAGNOSES.csv'), dtype={'ICD9_CODE': str})
diag_desc = diag_desc.drop(['ROW_ID', 'SHORT_TITLE'], axis=1)

# PROCEDURE CODES
proc_desc = pd.read_csv(os.path.join(root, 'data', 'external', 'D_ICD_PROCEDURES.csv'), dtype={'ICD9_CODE': str})
proc_desc = proc_desc.drop(['ROW_ID', 'SHORT_TITLE'], axis=1)


# Transform relative codes to absolute codes
diag_desc['ICD9_CODE'] = diag_desc.apply(lambda x: rel2abs(x.ICD9_CODE, flag_proc=False), axis=1)
proc_desc['ICD9_CODE'] = proc_desc.apply(lambda x: rel2abs(x.ICD9_CODE, flag_proc=True), axis=1)

display(diag_desc.head(5))
display(proc_desc.head(5))
# Out:
#   ICD9_CODE                                         LONG_TITLE
# 0    011.66  Tuberculous pneumonia [any form], tubercle bac...
# 1    011.70              Tuberculous pneumothorax, unspecified
# 2    011.71  Tuberculous pneumothorax, bacteriological or h...
# 3    011.72  Tuberculous pneumothorax, bacteriological or h...
# 4    011.73  Tuberculous pneumothorax, tubercle bacilli fou...
#   ICD9_CODE                                         LONG_TITLE
# 0     08.51                                         Canthotomy
# 1     08.52                                    Blepharorrhaphy
# 2     08.59                   Other adjustment of lid position
# 3     08.61   Reconstruction of eyelid with skin flap or graft
# 4     08.62  Reconstruction of eyelid with mucous membrane ...

# %% [markdown]
# # 2. Load MIMIC-III Data

# %%
# Load processed ICD-9 codes in complete MIMIC-III dataset
codes = pd.read_csv(os.path.join(root, 'data', 'processed', 'ALL_CODES.csv'), dtype={'ICD9_CODE': str})
display(codes.head(5))

# Load processed MimicFull dataset
MimicFull = pd.read_pickle(os.path.join(root, 'data', 'processed', 'data_MimicFull', 'DATA_MimicFull.pkl'))
display(MimicFull.head(5))
# Out:
#    SUBJECT_ID  HADM_ID ICD9_CODE  ICD9_TYPE
# 0         109   172335    403.01  diagnosis
# 1         109   172335       486  diagnosis
# 2         109   172335    582.81  diagnosis
# 3         109   172335     585.5  diagnosis
# 4         109   172335     425.4  diagnosis
#    SUBJECT_ID  HADM_ID                                          ICD9_CODE  \
# 0           3   145834  [038.9, 263.9, 38.93, 410.71, 425.4, 427.5, 42...
# 1           4   185777  [041.11, 042, 136.3, 276.3, 33.23, 38.93, 571....
# 2           6   107064  [275.3, 276.6, 276.7, 285.9, 38.06, 39.57, 403...
# 3           9   150750  [276.5, 401.9, 428.0, 431, 507.0, 584.9, 96.04...
# 4          10   184167  [765.15, 765.25, 774.2, 96.6, 99.15, 99.83, V2...
#
#                                                 TEXT  \
# 0  admission date : deidentified discharge date :...
# 1  admission date : deidentified discharge date :...
# 2  admission date : deidentified discharge date :...
# 3  admission date : deidentified discharge date :...
# 4  admission date : deidentified discharge date :...
#
#                                               TOKENS
# 0  [admission, date, :, deidentified, discharge, ...
# 1  [admission, date, :, deidentified, discharge, ...
# 2  [admission, date, :, deidentified, discharge, ...
# 3  [admission, date, :, deidentified, discharge, ...
# 4  [admission, date, :, deidentified, discharge, ...

# %%
# Next we want to make sure to only include codes that are actually associated with the hospital admission ids
# in the MimicFull dataset
MimicFull_hadm = MimicFull.HADM_ID.unique().tolist()

# Now use these hospital admission ids to subset the complete codes dataset
codes_full = codes[codes['HADM_ID'].isin(MimicFull_hadm)].copy()
codes_full = codes_full[['ICD9_CODE', 'ICD9_TYPE']]
codes_full = codes_full.drop_duplicates()

# Split this dataframe into diagnosis codes and procedure codes
codes_diag = codes_full[codes_full['ICD9_TYPE'] == 'diagnosis']
codes_proc = codes_full[codes_full['ICD9_TYPE'] == 'procedure']

# %% [markdown]
# # 3. Retrieve available code descriptions

# %%
# Retrieve all available code descriptions for the codes in the MimicFull dataset
diag_desc_full = diag_desc[diag_desc['ICD9_CODE'].isin(codes_diag.ICD9_CODE.unique().tolist())]
proc_desc_full = proc_desc[proc_desc['ICD9_CODE'].isin(codes_proc.ICD9_CODE.unique().tolist())]

print(f'Number of retrieved diagnosis code descriptions: {diag_desc_full.shape[0]}/{codes_diag.shape[0]}')
print(f'Number of retrieved procedure code descriptions: {proc_desc_full.shape[0]}/{codes_proc.shape[0]}')
print()
print('Retrieved sample diagnosis codes with description:')
display(diag_desc_full.sample(10))
print('Retrieved sample procedure codes with description:')
display(proc_desc_full.sample(10))
# Out:
# Number of retrieved diagnosis code descriptions: 6776/6918
# Number of retrieved procedure code descriptions: 1817/1989
#
# Retrieved sample diagnosis codes with description:
#       ICD9_CODE                                         LONG_TITLE
# 2971     307.81                                   Tension headache
# 2884     304.72  Combinations of opioid type drug with any othe...
# 11939     721.2            Thoracic spondylosis without myelopathy
# 9853     V09.90  Infection with drug-resistant microorganisms, ...
# 2890     304.90           Unspecified drug dependence, unspecified
# 4185     379.99                 Other ill-defined disorders of eye
# 5921      589.0                            Unilateral small kidney
# 7595     747.22                      Atresia and stenosis of aorta
# 7461     755.02                                Polydactyly of toes
# 10632    E866.8  Accidental poisoning by other specified solid ...
# Retrieved sample procedure codes with description:
#      ICD9_CODE                                         LONG_TITLE
# 658      39.58  Repair of blood vessel with unspecified type o...
# 1700     45.22  Endoscopy of large intestine through artificia...
# 888      27.56                  Other skin graft to lip and mouth
# 1610     37.66       Insertion of implantable heart assist system
# 1480     56.74                               Ureteroneocystostomy
# 999      18.21                     Excision of preauricular sinus
# 1902     83.03                                          Bursotomy
# 2515     81.85                              Other repair of elbow
# 2500     81.63                Fusion or refusion of 4-8 vertebrae
# 2305     62.69                             Other repair of testis

# %% [markdown]
# ### Let's take a look at the ICD-9 codes in MIMIC-III where we were unable to retrieve a respective code description.

# %%
# Show ICD-9 codes not retrieved
diag_desc_full_not = codes_diag[~codes_diag['ICD9_CODE'].isin(diag_desc_full.ICD9_CODE.unique().tolist())]

print('Sample diagnosis codes unable to retrieve appropriate descriptions')
display(diag_desc_full_not.sort_values('ICD9_CODE').sample(10))

proc_desc_full_not = codes_proc[~codes_proc['ICD9_CODE'].isin(proc_desc_full.ICD9_CODE.unique().tolist())]

print('Sample procedure codes unable to retrieve appropriate descriptions')
display(proc_desc_full_not.sort_values('ICD9_CODE').sample(10))
# Out:
# Sample diagnosis codes unable to retrieve appropriate descriptions
#        ICD9_CODE  ICD9_TYPE
# 164821     523.4  diagnosis
# 252527     616.8  diagnosis
# 536        V46.1  diagnosis
# 814        V17.4  diagnosis
# 122295     284.0  diagnosis
# 14543      357.8  diagnosis
# 172194     277.8  diagnosis
# 3977       780.9  diagnosis
# 115599     608.2  diagnosis
# 56316      282.4  diagnosis
# Sample procedure codes unable to retrieve appropriate descriptions
#        ICD9_CODE  ICD9_TYPE
# 724800        33  procedure
# 655314      45.8  procedure
# 848951      35.1  procedure
# 829101      76.4  procedure
# 729912        75  procedure
# 656596      11.8  procedure
# 815047      76.1  procedure
# 683872        45  procedure
# 720980        42  procedure
# 789162      33.2  procedure

# %% [markdown]
# ### Let's cross-compare with original list of ICD-9 code descriptions (DIAGNOSES AND PROCEDURES) retrieved from (https://www.cms.gov/Medicare/Coding/ICD9ProviderDiagnosticCodes/codes - Version 32 Full and Abbreviated Code Titles  – Effective October 1, 2014 (ZIP))
#
# Reasons why code descriptions were not retrieved
# - Assigned code (in MIMIC-III) was overly generic and not specific enough (Shi et al. 2017)
#     - See for diagnosis codes: 771.8 vs 771.81 / 771.82 / 771.83 / 771.89 (https://www.aapc.com/codes/icd9-codes-range/105/)
#     - See for procedure codes: 72 vs. 72.0 / 72.1 (https://www.aapc.com/codes/icd9-codes-vol3-range/15/)

# %%
# Load additional icd-9 code information
diag_desc2 = pd.read_excel(os.path.join(root, 'data', 'external', 'CMS32_DESC_LONG_SHORT_DX.xlsx'))
proc_desc2 = pd.read_excel(os.path.join(root, 'data', 'external', 'CMS32_DESC_LONG_SHORT_SG.xlsx'),
                          converters={'PROCEDURE CODE': str})

# %%
diag_desc2['ICD9_CODE'] = diag_desc2.apply(lambda x: rel2abs(x['DIAGNOSIS CODE'], flag_proc=False), axis=1)
diag_desc2 = diag_desc2.drop(['DIAGNOSIS CODE', 'SHORT DESCRIPTION'], axis=1)
diag_desc2
# Out:
#                                         LONG DESCRIPTION ICD9_CODE
# 0                         Cholera due to vibrio cholerae     001.0
# 1                  Cholera due to vibrio cholerae el tor     001.1
# 2                                   Cholera, unspecified     001.9
# 3                                          Typhoid fever     002.0
# 4                                    Paratyphoid fever A     002.1
# ...                                                  ...       ...
# 14562  Quadruplet gestation, unable to determine numb...    V91.29
# 14563  Other specified multiple gestation, unspecifie...    V91.90
# 14564  Other specified multiple gestation, with two o...    V91.91
# 14565  Other specified multiple gestation, with two o...    V91.92
# 14566  Other specified multiple gestation, unable to ...    V91.99
#
# [14567 rows x 2 columns]

# %%
proc_desc2['ICD9_CODE'] = proc_desc2.apply(lambda x: rel2abs(x['PROCEDURE CODE'], flag_proc=True), axis=1)
proc_desc2 = proc_desc2.drop(['PROCEDURE CODE', 'SHORT DESCRIPTION'], axis=1)
display(proc_desc2.head(10))
# Out:
#                                     LONG DESCRIPTION ICD9_CODE
# 0  Therapeutic ultrasound of vessels of head and ...     00.01
# 1                    Therapeutic ultrasound of heart     00.02
# 2  Therapeutic ultrasound of peripheral vascular ...     00.03
# 3                       Other therapeutic ultrasound     00.09
# 4             Implantation of chemotherapeutic agent     00.10
# 5           Infusion of drotrecogin alfa (activated)     00.11
# 6             Administration of inhaled nitric oxide     00.12
# 7                Injection or infusion of nesiritide     00.13
# 8  Injection or infusion of oxazolidinone class o...     00.14
# 9            High-dose infusion interleukin-2 [IL-2]     00.15

# %%
# Combine procedure and diagnosis label descriptions
descs = pd.concat([diag_desc_full, proc_desc_full]).sort_values('ICD9_CODE')

with open(os.path.join(root, 'data', 'processed', 'code_descriptions.pkl'), 'wb') as f:
    pickle.dump(descs, f)
    
display(descs.head(5))
descs.shape
# Out:
#    ICD9_CODE                             LONG_TITLE
# 68     003.0             Salmonella gastroenteritis
# 69     003.1                  Salmonella septicemia
# 76     003.8  Other specified salmonella infections
# 77     003.9      Salmonella infection, unspecified
# 79     004.1                      Shigella flexneri
# (8593, 2)

# %% [markdown]
# # Clean code descriptions

# %%
# Clean available code-descriptions
descs['desc_clean'] = descs.apply(lambda x: clean_desc(text=x.LONG_TITLE), axis=1)
descs = descs.drop(['LONG_TITLE'], axis=1)
descs['desc_len'] = descs.apply(lambda x: len(x.desc_clean), axis=1) 
max_len = descs.desc_len.max() 
print(f'Longest code description contains {max_len} tokens.')
# Out:
# Longest code description contains 20 tokens.

# %%
descs
# Out:
#      ICD9_CODE                                         desc_clean  desc_len
# 68       003.0                      [salmonella, gastroenteritis]         2
# 69       003.1                           [salmonella, septicemia]         2
# 76       003.8                [specified, salmonella, infections]         3
# 77       003.9               [salmonella, infection, unspecified]         3
# 79       004.1                               [shigella, flexneri]         2
# ...        ...                                                ...       ...
# 9750    V90.10          [retained, metal, fragments, unspecified]         4
# 9757    V90.39                     [retained, organic, fragments]         3
# 9758    V90.81                       [retained, glass, fragments]         3
# 9760    V90.89               [specified, retained, foreign, body]         4
# 9765    V91.03  [twin, gestation, dichorionicdiamniotic, place...         6
#
# [8593 rows x 3 columns]

# %% [markdown]
# # Create Docs and Tags for Doc2Vec Algorithm
# - Docs: Cleaned code descriptions
# - Tags: Respective ICD-9 Code Descriptions

# %%
docs = descs['desc_clean'].tolist()  # corpus to learn code descriptions - one doc is one label description
tags = descs['ICD9_CODE'].tolist()  # assign labels as tags

# %%
# Examples of cleaned descriptions
docs[:3]
# Out:
# [['salmonella', 'gastroenteritis'],
#  ['salmonella', 'septicemia'],
#  ['specified', 'salmonella', 'infections']]

# %% [markdown]
# # Compute Code Description Embedding Matrices using Doc2Vec

# %%
documents = [TaggedDocument(doc, [tag]) for doc, tag in zip(docs, tags)]

# %%
documents[:3]
# Out:
# [TaggedDocument(words=['salmonella', 'gastroenteritis'], tags=['003.0']),
#  TaggedDocument(words=['salmonella', 'septicemia'], tags=['003.1']),
#  TaggedDocument(words=['specified', 'salmonella', 'infections'], tags=['003.8'])]

# %%
with open(os.path.join(root, 'data', 'processed', 'data_MimicFull', 'l_codes_MimicFull.pkl'), 'rb') as f:
    labels_full = pickle.load(f)
    
with open(os.path.join(root, 'data', 'processed', 'data_Mimic50', 'l_codes_Mimic50.pkl'), 'rb') as f:
    labels_50 = pickle.load(f)
    
# Compute pre-trained word embeddings for embedding layer using Word2Vec
documents = [TaggedDocument(doc, [tag]) for doc, tag in zip(docs, tags)]
embedding_dims = [100, 200, 300]


for subset, labels in zip(['MimicFull', 'Mimic50'], [labels_full, labels_50]):
    print(f'Create code description embedding matrix for {subset}')
    if not os.path.exists(os.path.join(path_data_proc, f'data_{subset}', 'code_embeddings')):
        os.makedirs(os.path.join(path_data_proc, f'data_{subset}', 'code_embeddings'))
    for dim in embedding_dims:
        print(f'Embedding dimension: {dim}')
        model = Doc2Vec(documents, vector_size=dim, window=2, min_count=1, workers=4)
        model_shape = model.dv.vectors.shape    
        label_embedding_matrix = np.zeros((len(labels), dim))    
        count = 0
        for i, label in enumerate(labels):
            try:
                dv = model.dv[label]
            except:
                count += 1
                # create randomly initialized code description embedding vector 
                dv = np.random.uniform(low=-0.05, high=0.05, size=(dim, ))

            label_embedding_matrix[i,:] = dv
        print(f'Shape of label_embedding_matrix: {label_embedding_matrix.shape}')
    
        print(f'Number of randomly initialized label description embedding vectors {count}.')
    
        with open(os.path.join(root, 'data', 'processed', f'data_{subset}', 'code_embeddings', f'code_embedding_matrix_{subset}_{dim}.pkl'), 'wb') as f:
            pickle.dump(label_embedding_matrix, f)
# Out:
# Create code description embedding matrix for MimicFull
# Embedding dimension: 100
# Shape of label_embedding_matrix: (8907, 100)
# Number of randomly initialized label description embedding vectors 314.
# Embedding dimension: 200
# Shape of label_embedding_matrix: (8907, 200)
# Number of randomly initialized label description embedding vectors 314.
# Embedding dimension: 300
# Shape of label_embedding_matrix: (8907, 300)
# Number of randomly initialized label description embedding vectors 314.
# Create code description embedding matrix for Mimic50
# Embedding dimension: 100
# Shape of label_embedding_matrix: (50, 100)
# Number of randomly initialized label description embedding vectors 0.
# Embedding dimension: 200
# Shape of label_embedding_matrix: (50, 200)
# Number of randomly initialized label description embedding vectors 0.
# Embedding dimension: 300
# Shape of label_embedding_matrix: (50, 300)
# Number of randomly initialized label description embedding vectors 0.

# %% [markdown]
# # Preprocess High-Level ICD-9 Code Categories

# %% [markdown]
# ## MIMIC-III-Full

# %%
# Dictionary containing ICD-9 diagnosis (3 digits + V/E) / procedure codes (2 digits)
# Diagnosis codes: http://www.icd9data.com/2015/Volume1/default.htm
# Procedure codes: http://www.icd9data.com/2015/Volume3/default.htm

d_cat_desc = {
    '001-139': 'Infectious And Parasitic Diseases',
    '140-239': 'Neoplasms',
    '240-279': 'Endocrine, Nutritional And Metabolic Diseases, And Immunity Disorders',
    '280-289': 'Diseases Of The Blood And Blood-Forming Organs',
    '290-319': 'Mental Disorders',
    '320-389': 'Diseases Of The Nervous System And Sense Organs',
    '390-459': 'Diseases Of The Circulatory System',
    '460-519': 'Diseases Of The Respiratory System',
    '520-579': 'Diseases Of The Digestive System',
    '580-629': 'Diseases Of The Genitourinary System',
    '630-679': 'Complications Of Pregnancy, Childbirth, And The Puerperium',
    '680-709': 'Diseases Of The Skin And Subcutaneous Tissue',
    '710-739': 'Diseases Of The Musculoskeletal System And Connective Tissue',
    '740-759': 'Congenital Anomalies',
    '760-779': 'Certain Conditions Originating In The Perinatal Period',
    '780-799': 'Symptoms, Signs, And Ill-Defined Conditions',
    '800-999': 'Injury And Poisoning',
    'V01-V91': 'Supplementary Classification Of Factors Influencing Health Status And Contact With Health Services',
    'E000-E999': 'Supplementary Classification Of External Causes Of Injury And Poisoning',
    '00-00': 'Procedures And Interventions Not Elsewhere Classified',
    '01-05': 'Operations On The Nervous System',
    '06-07': 'Operations On The Endocrine System',
    '08-16': 'Operations On The Eye',
    '17-17': 'Other Miscellaneous Diagnostic And Therapeutic Procedures',
    '18-20': 'Operations On The Ear',
    '21-29': 'Operations On The Nose, Mouth, And Pharynx',
    '30-34': 'Operations On The Respiratory System',
    '35-39': 'Operations On The Cardiovascular System',
    '40-41': 'Operations On The Hemic And Lymphatic System',
    '42-54': 'Operations On The Digestive System',
    '55-59': 'Operations On The Urinary System',
    '60-64': 'Operations On The Male Genital Organs',
    '65-71': 'Operations On The Female Genital Organs',
    '72-75': 'Obstetrical Procedures',
    '76-84': 'Operations On The Musculoskeletal System',
    '85-86': 'Operations On The Integumentary System',
    '87-99': 'Miscellaneous Diagnostic And Therapeutic Procedures'
}

# %%
df_cat_desc = pd.DataFrame.from_dict(data=d_cat_desc.items())
df_cat_desc.columns = ['categories', 'description']
df_cat_desc

df_cat_desc['desc_clean'] = df_cat_desc.apply(lambda x: clean_desc(text=x.description), axis=1)
display(df_cat_desc)


docs = df_cat_desc['desc_clean'].tolist()  # corpus to learn code descriptions - one doc is one label description
tags = df_cat_desc['categories'].tolist()  # assign labels as tags
# Out:
#    categories                                        description  \
# 0     001-139                  Infectious And Parasitic Diseases
# 1     140-239                                          Neoplasms
# 2     240-279  Endocrine, Nutritional And Metabolic Diseases,...
# 3     280-289     Diseases Of The Blood And Blood-Forming Organs
# 4     290-319                                   Mental Disorders
# 5     320-389    Diseases Of The Nervous System And Sense Organs
# 6     390-459                 Diseases Of The Circulatory System
# 7     460-519                 Diseases Of The Respiratory System
# 8     520-579                   Diseases Of The Digestive System
# 9     580-629               Diseases Of The Genitourinary System
# 10    630-679  Complications Of Pregnancy, Childbirth, And Th...
# 11    680-709       Diseases Of The Skin And Subcutaneous Tissue
# 12    710-739  Diseases Of The Musculoskeletal System And Con...
# 13    740-759                               Congenital Anomalies
# 14    760-779  Certain Conditions Originating In The Perinata...
# 15    780-799        Symptoms, Signs, And Ill-Defined Conditions
# 16    800-999                               Injury And Poisoning
# 17    V01-V91  Supplementary Classification Of Factors Influe...
# 18  E000-E999  Supplementary Classification Of External Cause...
# 19      00-00  Procedures And Interventions Not Elsewhere Cla...
# 20      01-05                   Operations On The Nervous System
# 21      06-07                 Operations On The Endocrine System
# 22      08-16                              Operations On The Eye
# 23      17-17  Other Miscellaneous Diagnostic And Therapeutic...
# 24      18-20                              Operations On The Ear
# 25      21-29         Operations On The Nose, Mouth, And Pharynx
# 26      30-34               Operations On The Respiratory System
# 27      35-39            Operations On The Cardiovascular System
# 28      40-41       Operations On The Hemic And Lymphatic System
# 29      42-54                 Operations On The Digestive System
# 30      55-59                   Operations On The Urinary System
# 31      60-64              Operations On The Male Genital Organs
# 32      65-71            Operations On The Female Genital Organs
# 33      72-75                             Obstetrical Procedures
# 34      76-84           Operations On The Musculoskeletal System
# 35      85-86             Operations On The Integumentary System
# 36      87-99  Miscellaneous Diagnostic And Therapeutic Proce...
#
#                                            desc_clean
# 0                   [infectious, parasitic, diseases]
# 1                                         [neoplasms]
# 2   [endocrine, nutritional, metabolic, diseases, ...
# 3             [diseases, blood, bloodforming, organs]
# 4                                 [mental, disorders]
# 5                 [diseases, nervous, system, organs]
# 6                     [diseases, circulatory, system]
# 7                     [diseases, respiratory, system]
# 8                       [diseases, digestive, system]
# 9                   [diseases, genitourinary, system]
# 10  [complications, pregnancy, childbirth, puerper...
# 11             [diseases, skin, subcutaneous, tissue]
# 12  [diseases, musculoskeletal, system, connective...
# 13                            [congenital, anomalies]
# 14       [conditions, originating, perinatal, period]
# 15          [symptoms, signs, illdefined, conditions]
# 16                                [injury, poisoning]
# 17  [supplementary, classification, factors, influ...
# 18  [supplementary, classification, external, inju...
# 19            [procedures, interventions, classified]
# 20                      [operations, nervous, system]
# 21                    [operations, endocrine, system]
# 22                                  [operations, eye]
# 23  [miscellaneous, diagnostic, therapeutic, proce...
# 24                                  [operations, ear]
# 25                 [operations, nose, mouth, pharynx]
# 26                  [operations, respiratory, system]
# 27               [operations, cardiovascular, system]
# 28             [operations, hemic, lymphatic, system]
# 29                    [operations, digestive, system]
# 30                      [operations, urinary, system]
# 31                [operations, male, genital, organs]
# 32              [operations, female, genital, organs]
# 33                          [obstetrical, procedures]
# 34              [operations, musculoskeletal, system]
# 35                [operations, integumentary, system]
# 36  [miscellaneous, diagnostic, therapeutic, proce...

# %%
# Compute pre-trained word embeddings for embedding layer using Word2Vec
documents = [TaggedDocument(doc, [tag]) for doc, tag in zip(docs, tags)]
embedding_dims = [100, 200, 300]
for dim in embedding_dims:
    print()
    print(f'Create word embedding matrices with dimenions: {dim}')
    model = Doc2Vec(documents, vector_size=dim, window=2, min_count=1, workers=4)
    model_shape = model.dv.vectors.shape
    print('Shape of document embedding matrix.')
    print(f'Number of document embeddings: {model_shape[0]}')
    print(f'Document embedding dimension: {model_shape[1]}')
        
    label_embedding_matrix = model.dv.vectors
    with open(os.path.join(root, 'data', 'processed', 'data_MimicFull', 'code_embeddings', f'cat_embedding_matrix_MimicFull_{dim}.pkl'), 'wb') as f:
        pickle.dump(label_embedding_matrix, f)
    print()
# Out:
# Create word embedding matrices with dimenions: 100
# Shape of document embedding matrix.
# Number of document embeddings: 37
# Document embedding dimension: 100
#
#
# Create word embedding matrices with dimenions: 200
# Shape of document embedding matrix.
# Number of document embeddings: 37
# Document embedding dimension: 200
#
#
# Create word embedding matrices with dimenions: 300
# Shape of document embedding matrix.
# Number of document embeddings: 37
# Document embedding dimension: 300

# %% [markdown]
# ### Retrieve Category to billable Code Mapping

# %%
df_cat = pd.DataFrame.from_dict(data=d_cat_desc.items())
df_cat.columns = ['categories', 'description']

cat_bounds = df_cat['categories'].str.split("-", n = 1, expand = True)
df_cat['cat_lower'] = cat_bounds[0]
df_cat['cat_upper'] = cat_bounds[1]
df_cat
# Out:
#    categories                                        description cat_lower  \
# 0     001-139                  Infectious And Parasitic Diseases       001
# 1     140-239                                          Neoplasms       140
# 2     240-279  Endocrine, Nutritional And Metabolic Diseases,...       240
# 3     280-289     Diseases Of The Blood And Blood-Forming Organs       280
# 4     290-319                                   Mental Disorders       290
# 5     320-389    Diseases Of The Nervous System And Sense Organs       320
# 6     390-459                 Diseases Of The Circulatory System       390
# 7     460-519                 Diseases Of The Respiratory System       460
# 8     520-579                   Diseases Of The Digestive System       520
# 9     580-629               Diseases Of The Genitourinary System       580
# 10    630-679  Complications Of Pregnancy, Childbirth, And Th...       630
# 11    680-709       Diseases Of The Skin And Subcutaneous Tissue       680
# 12    710-739  Diseases Of The Musculoskeletal System And Con...       710
# 13    740-759                               Congenital Anomalies       740
# 14    760-779  Certain Conditions Originating In The Perinata...       760
# 15    780-799        Symptoms, Signs, And Ill-Defined Conditions       780
# 16    800-999                               Injury And Poisoning       800
# 17    V01-V91  Supplementary Classification Of Factors Influe...       V01
# 18  E000-E999  Supplementary Classification Of External Cause...      E000
# 19      00-00  Procedures And Interventions Not Elsewhere Cla...        00
# 20      01-05                   Operations On The Nervous System        01
# 21      06-07                 Operations On The Endocrine System        06
# 22      08-16                              Operations On The Eye        08
# 23      17-17  Other Miscellaneous Diagnostic And Therapeutic...        17
# 24      18-20                              Operations On The Ear        18
# 25      21-29         Operations On The Nose, Mouth, And Pharynx        21
# 26      30-34               Operations On The Respiratory System        30
# 27      35-39            Operations On The Cardiovascular System        35
# 28      40-41       Operations On The Hemic And Lymphatic System        40
# 29      42-54                 Operations On The Digestive System        42
# 30      55-59                   Operations On The Urinary System        55
# 31      60-64              Operations On The Male Genital Organs        60
# 32      65-71            Operations On The Female Genital Organs        65
# 33      72-75                             Obstetrical Procedures        72
# 34      76-84           Operations On The Musculoskeletal System        76
# 35      85-86             Operations On The Integumentary System        85
# 36      87-99  Miscellaneous Diagnostic And Therapeutic Proce...        87
#
#    cat_upper
# 0        139
# 1        239
# 2        279
# 3        289
# 4        319
# 5        389
# 6        459
# 7        519
# 8        579
# 9        629
# 10       679
# 11       709
# 12       739
# 13       759
# 14       779
# 15       799
# 16       999
# 17       V91
# 18      E999
# 19        00
# 20        05
# 21        07
# 22        16
# 23        17
# 24        20
# 25        29
# 26        34
# 27        39
# 28        41
# 29        54
# 30        59
# 31        64
# 32        71
# 33        75
# 34        84
# 35        86
# 36        99

# %%
lower_bounds = list(cat_bounds[0])
upper_bounds = list(cat_bounds[1])

# %%
cat2label_mapping_full = []
for label in labels_full:
    for i, (lower, upper) in enumerate(zip(lower_bounds, upper_bounds)):
        if '.' in label:
            if label[2] == '.':  # procedure code
                if len(lower) == 2:
                    if lower <= label[:2] <= upper:
                        print(f'Code: {label} -> Cat: {i}')
                        cat2label_mapping_full.append(i)
            else:  # diagnosis code
                if len(lower) == 3:
                    if lower <= label[:3] <= upper:
                        print(f'Code: {label} -> Cat: {i}')
                        cat2label_mapping_full.append(i)
                elif len(lower) == 4:  # codes starting with 'E'
                    if lower <= label[:4] <= upper:
                        print(f'Code: {label} -> Cat: {i}')
                        cat2label_mapping_full.append(i)
        else:
            if len(label) == 2:
                if len(lower) == 2:
                    if lower <= label <= upper:
                        print(f'Code: {label} -> Cat: {i}')
                        cat2label_mapping_full.append(i)
            elif len(label) == 3:
                if len(lower) == 3:
                    if lower <= label <= upper:
                        print(f'Code: {label} -> Cat: {i}')
                        cat2label_mapping_full.append(i)
            elif len(label) == 4:
                if len(lower) == 4:
                    if lower <= label <= upper:
                        print(f'Code: {label} -> Cat: {i}')
                        cat2label_mapping_full.append(i)
# Out:
# Code: 003.0 -> Cat: 0
# Code: 003.1 -> Cat: 0
# Code: 003.8 -> Cat: 0
# Code: 003.9 -> Cat: 0
# Code: 004.1 -> Cat: 0
# Code: 004.8 -> Cat: 0
# Code: 004.9 -> Cat: 0
# Code: 005.1 -> Cat: 0
# Code: 005.81 -> Cat: 0
# Code: 005.9 -> Cat: 0
# Code: 007.1 -> Cat: 0
# Code: 007.4 -> Cat: 0
# Code: 008.04 -> Cat: 0
# Code: 008.41 -> Cat: 0
# Code: 008.43 -> Cat: 0
# Code: 008.45 -> Cat: 0
# Code: 008.47 -> Cat: 0
# Code: 008.5 -> Cat: 0
# Code: 008.61 -> Cat: 0
# Code: 008.62 -> Cat: 0
# Code: 008.63 -> Cat: 0
# Code: 008.69 -> Cat: 0
# Code: 008.8 -> Cat: 0
# Code: 009.0 -> Cat: 0
# Code: 009.1 -> Cat: 0
# Code: 009.2 -> Cat: 0
# Code: 009.3 -> Cat: 0
# Code: 010.85 -> Cat: 0
# Code: 011.23 -> Cat: 0
# Code: 011.36 -> Cat: 0
# Code: 011.64 -> Cat: 0
# Code: 011.86 -> Cat: 0
# Code: 011.90 -> Cat: 0
# Code: 011.93 -> Cat: 0
# Code: 011.94 -> Cat: 0
# Code: 012.05 -> Cat: 0
# Code: 012.15 -> Cat: 0
# Code: 013.00 -> Cat: 0
# Code: 013.04 -> Cat: 0
# Code: 013.25 -> Cat: 0
# Code: 013.30 -> Cat: 0
# Code: 013.54 -> Cat: 0
# Code: 014.02 -> Cat: 0
# Code: 014.05 -> Cat: 0
# Code: 014.85 -> Cat: 0
# Code: 015.04 -> Cat: 0
# Code: 015.05 -> Cat: 0
# Code: 018.03 -> Cat: 0
# Code: 018.05 -> Cat: 0
# Code: 018.80 -> Cat: 0
# Code: 018.90 -> Cat: 0
# Code: 018.94 -> Cat: 0
# Code: 018.95 -> Cat: 0
# Code: 018.96 -> Cat: 0
# Code: 021.8 -> Cat: 0
# Code: 023.9 -> Cat: 0
# Code: 027.0 -> Cat: 0
# Code: 027.2 -> Cat: 0
# Code: 027.9 -> Cat: 0
# Code: 030.9 -> Cat: 0
# Code: 031.0 -> Cat: 0
# Code: 031.1 -> Cat: 0
# Code: 031.2 -> Cat: 0
# Code: 031.8 -> Cat: 0
# Code: 031.9 -> Cat: 0
# Code: 032.85 -> Cat: 0
# Code: 032.89 -> Cat: 0
# Code: 032.9 -> Cat: 0
# Code: 033.8 -> Cat: 0
# Code: 034.0 -> Cat: 0
# Code: 035 -> Cat: 0
# Code: 036.0 -> Cat: 0
# Code: 036.2 -> Cat: 0
# Code: 036.41 -> Cat: 0
# Code: 038.0 -> Cat: 0
# Code: 038.10 -> Cat: 0
# Code: 038.11 -> Cat: 0
# Code: 038.12 -> Cat: 0
# Code: 038.19 -> Cat: 0
# Code: 038.2 -> Cat: 0
# Code: 038.3 -> Cat: 0
# Code: 038.40 -> Cat: 0
# Code: 038.41 -> Cat: 0
# Code: 038.42 -> Cat: 0
# Code: 038.43 -> Cat: 0
# Code: 038.44 -> Cat: 0
# Code: 038.49 -> Cat: 0
# Code: 038.8 -> Cat: 0
# Code: 038.9 -> Cat: 0
# Code: 039.1 -> Cat: 0
# Code: 039.2 -> Cat: 0
# Code: 039.8 -> Cat: 0
# Code: 040.0 -> Cat: 0
# Code: 040.82 -> Cat: 0
# Code: 040.89 -> Cat: 0
# Code: 041.00 -> Cat: 0
# Code: 041.01 -> Cat: 0
# Code: 041.02 -> Cat: 0
# Code: 041.03 -> Cat: 0
# Code: 041.04 -> Cat: 0
# Code: 041.05 -> Cat: 0
# Code: 041.09 -> Cat: 0
# Code: 041.10 -> Cat: 0
# Code: 041.11 -> Cat: 0
# Code: 041.12 -> Cat: 0
# Code: 041.19 -> Cat: 0
# Code: 041.2 -> Cat: 0
# Code: 041.3 -> Cat: 0
# Code: 041.4 -> Cat: 0
# Code: 041.49 -> Cat: 0
# Code: 041.5 -> Cat: 0
# Code: 041.6 -> Cat: 0
# Code: 041.7 -> Cat: 0
# Code: 041.82 -> Cat: 0
# Code: 041.83 -> Cat: 0
# Code: 041.84 -> Cat: 0
# Code: 041.85 -> Cat: 0
# Code: 041.86 -> Cat: 0
# Code: 041.89 -> Cat: 0
# Code: 041.9 -> Cat: 0
# Code: 042 -> Cat: 0
# Code: 045.90 -> Cat: 0
# Code: 046.3 -> Cat: 0
# Code: 046.71 -> Cat: 0
# Code: 047.0 -> Cat: 0
# Code: 047.8 -> Cat: 0
# Code: 047.9 -> Cat: 0
# Code: 048 -> Cat: 0
# Code: 049.0 -> Cat: 0
# Code: 049.1 -> Cat: 0
# Code: 049.8 -> Cat: 0
# Code: 049.9 -> Cat: 0
# Code: 052.0 -> Cat: 0
# Code: 052.1 -> Cat: 0
# Code: 052.7 -> Cat: 0
# Code: 052.9 -> Cat: 0
# Code: 053.0 -> Cat: 0
# Code: 053.11 -> Cat: 0
# Code: 053.12 -> Cat: 0
# Code: 053.13 -> Cat: 0
# Code: 053.14 -> Cat: 0
# Code: 053.19 -> Cat: 0
# Code: 053.20 -> Cat: 0
# Code: 053.29 -> Cat: 0
# Code: 053.71 -> Cat: 0
# Code: 053.79 -> Cat: 0
# Code: 053.9 -> Cat: 0
# Code: 054.0 -> Cat: 0
# Code: 054.10 -> Cat: 0
# Code: 054.12 -> Cat: 0
# Code: 054.13 -> Cat: 0
# Code: 054.19 -> Cat: 0
# Code: 054.2 -> Cat: 0
# Code: 054.3 -> Cat: 0
# Code: 054.40 -> Cat: 0
# Code: 054.43 -> Cat: 0
# Code: 054.5 -> Cat: 0
# Code: 054.71 -> Cat: 0
# Code: 054.72 -> Cat: 0
# Code: 054.79 -> Cat: 0
# Code: 054.9 -> Cat: 0
# Code: 057.8 -> Cat: 0
# Code: 057.9 -> Cat: 0
# Code: 058.21 -> Cat: 0
# Code: 058.29 -> Cat: 0
# Code: 058.81 -> Cat: 0
# Code: 058.89 -> Cat: 0
# Code: 062.2 -> Cat: 0
# Code: 066.41 -> Cat: 0
# Code: 066.42 -> Cat: 0
# Code: 070.0 -> Cat: 0
# Code: 070.1 -> Cat: 0
# Code: 070.20 -> Cat: 0
# Code: 070.22 -> Cat: 0
# Code: 070.30 -> Cat: 0
# Code: 070.31 -> Cat: 0
# Code: 070.32 -> Cat: 0
# Code: 070.33 -> Cat: 0
# Code: 070.41 -> Cat: 0
# Code: 070.44 -> Cat: 0
# Code: 070.49 -> Cat: 0
# Code: 070.51 -> Cat: 0
# Code: 070.52 -> Cat: 0
# Code: 070.53 -> Cat: 0
# Code: 070.54 -> Cat: 0
# Code: 070.59 -> Cat: 0
# Code: 070.70 -> Cat: 0
# Code: 070.71 -> Cat: 0
# Code: 070.9 -> Cat: 0
# Code: 075 -> Cat: 0
# Code: 077.8 -> Cat: 0
# Code: 077.99 -> Cat: 0
# Code: 078.0 -> Cat: 0
# Code: 078.10 -> Cat: 0
# Code: 078.11 -> Cat: 0
# Code: 078.19 -> Cat: 0
# Code: 078.5 -> Cat: 0
# Code: 078.89 -> Cat: 0
# Code: 079.0 -> Cat: 0
# Code: 079.3 -> Cat: 0
# Code: 079.4 -> Cat: 0
# Code: 079.51 -> Cat: 0
# Code: 079.53 -> Cat: 0
# Code: 079.6 -> Cat: 0
# Code: 079.83 -> Cat: 0
# Code: 079.89 -> Cat: 0
# Code: 079.98 -> Cat: 0
# Code: 079.99 -> Cat: 0
# Code: 082.40 -> Cat: 0
# Code: 082.49 -> Cat: 0
# Code: 083.9 -> Cat: 0
# Code: 084.0 -> Cat: 0
# Code: 084.4 -> Cat: 0
# Code: 084.6 -> Cat: 0
# Code: 084.9 -> Cat: 0
# Code: 085.9 -> Cat: 0
# Code: 086.0 -> Cat: 0
# Code: 088.0 -> Cat: 0
# Code: 088.81 -> Cat: 0
# Code: 088.82 -> Cat: 0
# Code: 090.2 -> Cat: 0
# Code: 091.2 -> Cat: 0
# Code: 091.52 -> Cat: 0
# Code: 091.81 -> Cat: 0
# Code: 091.9 -> Cat: 0
# Code: 093.1 -> Cat: 0
# Code: 094.0 -> Cat: 0
# Code: 094.9 -> Cat: 0
# Code: 096 -> Cat: 0
# Code: 097.0 -> Cat: 0
# Code: 097.1 -> Cat: 0
# Code: 097.9 -> Cat: 0
# Code: 098.0 -> Cat: 0
# Code: 099.3 -> Cat: 0
# Code: 10 -> Cat: 22
# Code: 10.1 -> Cat: 22
# Code: 10.2 -> Cat: 22
# Code: 10.6 -> Cat: 22
# Code: 10.9 -> Cat: 22
# Code: 11 -> Cat: 22
# Code: 11.0 -> Cat: 22
# Code: 11.3 -> Cat: 22
# Code: 11.4 -> Cat: 22
# Code: 11.49 -> Cat: 22
# Code: 11.51 -> Cat: 22
# Code: 11.8 -> Cat: 22
# Code: 110.0 -> Cat: 0
# Code: 110.1 -> Cat: 0
# Code: 110.3 -> Cat: 0
# Code: 110.4 -> Cat: 0
# Code: 110.5 -> Cat: 0
# Code: 110.6 -> Cat: 0
# Code: 110.8 -> Cat: 0
# Code: 110.9 -> Cat: 0
# Code: 111.0 -> Cat: 0
# Code: 111.8 -> Cat: 0
# Code: 111.9 -> Cat: 0
# Code: 112.0 -> Cat: 0
# Code: 112.1 -> Cat: 0
# Code: 112.2 -> Cat: 0
# Code: 112.3 -> Cat: 0
# Code: 112.4 -> Cat: 0
# Code: 112.5 -> Cat: 0
# Code: 112.81 -> Cat: 0
# Code: 112.83 -> Cat: 0
# Code: 112.84 -> Cat: 0
# Code: 112.85 -> Cat: 0
# Code: 112.89 -> Cat: 0
# Code: 112.9 -> Cat: 0
# Code: 114.0 -> Cat: 0
# Code: 114.9 -> Cat: 0
# Code: 115.05 -> Cat: 0
# Code: 115.19 -> Cat: 0
# Code: 115.90 -> Cat: 0
# Code: 115.99 -> Cat: 0
# Code: 116.0 -> Cat: 0
# Code: 117.3 -> Cat: 0
# Code: 117.4 -> Cat: 0
# Code: 117.5 -> Cat: 0
# Code: 117.7 -> Cat: 0
# Code: 117.9 -> Cat: 0
# Code: 118 -> Cat: 0
# Code: 12 -> Cat: 22
# Code: 12.0 -> Cat: 22
# Code: 12.1 -> Cat: 22
# Code: 12.2 -> Cat: 22
# Code: 12.3 -> Cat: 22
# Code: 12.4 -> Cat: 22
# Code: 12.5 -> Cat: 22
# Code: 12.6 -> Cat: 22
# Code: 12.64 -> Cat: 22
# Code: 12.7 -> Cat: 22
# Code: 12.73 -> Cat: 22
# Code: 12.8 -> Cat: 22
# Code: 12.81 -> Cat: 22
# Code: 12.91 -> Cat: 22
# Code: 12.92 -> Cat: 22
# Code: 120.8 -> Cat: 0
# Code: 120.9 -> Cat: 0
# Code: 121.1 -> Cat: 0
# Code: 122.8 -> Cat: 0
# Code: 123.1 -> Cat: 0
# Code: 125.1 -> Cat: 0
# Code: 127.0 -> Cat: 0
# Code: 127.2 -> Cat: 0
# Code: 127.3 -> Cat: 0
# Code: 13 -> Cat: 22
# Code: 13.1 -> Cat: 22
# Code: 13.2 -> Cat: 22
# Code: 13.41 -> Cat: 22
# Code: 13.71 -> Cat: 22
# Code: 13.9 -> Cat: 22
# Code: 130.0 -> Cat: 0
# Code: 130.7 -> Cat: 0
# Code: 130.8 -> Cat: 0
# Code: 130.9 -> Cat: 0
# Code: 131.01 -> Cat: 0
# Code: 131.02 -> Cat: 0
# Code: 131.09 -> Cat: 0
# Code: 132.0 -> Cat: 0
# Code: 132.9 -> Cat: 0
# Code: 133.0 -> Cat: 0
# Code: 134.8 -> Cat: 0
# Code: 135 -> Cat: 0
# Code: 136.1 -> Cat: 0
# Code: 136.3 -> Cat: 0
# Code: 136.9 -> Cat: 0
# Code: 137.0 -> Cat: 0
# Code: 137.3 -> Cat: 0
# Code: 138 -> Cat: 0
# Code: 139.0 -> Cat: 0
# Code: 139.8 -> Cat: 0
# Code: 14 -> Cat: 22
# Code: 14.22 -> Cat: 22
# Code: 14.24 -> Cat: 22
# Code: 14.34 -> Cat: 22
# Code: 14.41 -> Cat: 22
# Code: 14.54 -> Cat: 22
# Code: 14.59 -> Cat: 22
# Code: 14.73 -> Cat: 22
# Code: 14.74 -> Cat: 22
# Code: 14.75 -> Cat: 22
# Code: 14.79 -> Cat: 22
# Code: 14.9 -> Cat: 22
# Code: 140.0 -> Cat: 1
# Code: 140.1 -> Cat: 1
# Code: 140.9 -> Cat: 1
# Code: 141.0 -> Cat: 1
# Code: 141.4 -> Cat: 1
# Code: 141.8 -> Cat: 1
# Code: 141.9 -> Cat: 1
# Code: 142.0 -> Cat: 1
# Code: 142.9 -> Cat: 1
# Code: 143.0 -> Cat: 1
# Code: 143.1 -> Cat: 1
# Code: 144.0 -> Cat: 1
# Code: 144.8 -> Cat: 1
# Code: 144.9 -> Cat: 1
# Code: 145.0 -> Cat: 1
# Code: 145.2 -> Cat: 1
# Code: 145.3 -> Cat: 1
# Code: 145.5 -> Cat: 1
# Code: 145.8 -> Cat: 1
# Code: 146.0 -> Cat: 1
# Code: 146.1 -> Cat: 1
# Code: 146.3 -> Cat: 1
# Code: 146.4 -> Cat: 1
# Code: 146.7 -> Cat: 1
# Code: 146.8 -> Cat: 1
# Code: 146.9 -> Cat: 1
# Code: 147.1 -> Cat: 1
# Code: 147.8 -> Cat: 1
# Code: 147.9 -> Cat: 1
# Code: 148.1 -> Cat: 1
# Code: 148.8 -> Cat: 1
# Code: 148.9 -> Cat: 1
# Code: 149.0 -> Cat: 1
# Code: 149.8 -> Cat: 1
# Code: 15 -> Cat: 22
# Code: 15.1 -> Cat: 22
# Code: 15.2 -> Cat: 22
# Code: 15.3 -> Cat: 22
# Code: 15.7 -> Cat: 22
# Code: 15.9 -> Cat: 22
# Code: 150.0 -> Cat: 1
# Code: 150.1 -> Cat: 1
# Code: 150.3 -> Cat: 1
# Code: 150.4 -> Cat: 1
# Code: 150.5 -> Cat: 1
# Code: 150.8 -> Cat: 1
# Code: 150.9 -> Cat: 1
# Code: 151.0 -> Cat: 1
# Code: 151.1 -> Cat: 1
# Code: 151.2 -> Cat: 1
# Code: 151.3 -> Cat: 1
# Code: 151.4 -> Cat: 1
# Code: 151.5 -> Cat: 1
# Code: 151.6 -> Cat: 1
# Code: 151.8 -> Cat: 1
# Code: 151.9 -> Cat: 1
# Code: 152.0 -> Cat: 1
# Code: 152.1 -> Cat: 1
# Code: 152.2 -> Cat: 1
# Code: 152.8 -> Cat: 1
# Code: 152.9 -> Cat: 1
# Code: 153.0 -> Cat: 1
# Code: 153.1 -> Cat: 1
# Code: 153.2 -> Cat: 1
# Code: 153.3 -> Cat: 1
# Code: 153.4 -> Cat: 1
# Code: 153.5 -> Cat: 1
# Code: 153.6 -> Cat: 1
# Code: 153.7 -> Cat: 1
# Code: 153.8 -> Cat: 1
# Code: 153.9 -> Cat: 1
# Code: 154.0 -> Cat: 1
# Code: 154.1 -> Cat: 1
# Code: 154.2 -> Cat: 1
# Code: 154.3 -> Cat: 1
# Code: 154.8 -> Cat: 1
# Code: 155.0 -> Cat: 1
# Code: 155.1 -> Cat: 1
# Code: 155.2 -> Cat: 1
# Code: 156.0 -> Cat: 1
# Code: 156.1 -> Cat: 1
# Code: 156.2 -> Cat: 1
# Code: 156.8 -> Cat: 1
# Code: 156.9 -> Cat: 1
# Code: 157.0 -> Cat: 1
# Code: 157.1 -> Cat: 1
# Code: 157.2 -> Cat: 1
# Code: 157.3 -> Cat: 1
# Code: 157.4 -> Cat: 1
# Code: 157.8 -> Cat: 1
# Code: 157.9 -> Cat: 1
# Code: 158.0 -> Cat: 1
# Code: 158.8 -> Cat: 1
# Code: 158.9 -> Cat: 1
# Code: 159.8 -> Cat: 1
# Code: 159.9 -> Cat: 1
# Code: 16 -> Cat: 22
# Code: 16.09 -> Cat: 22
# Code: 16.31 -> Cat: 22
# Code: 16.49 -> Cat: 22
# Code: 16.51 -> Cat: 22
# Code: 16.52 -> Cat: 22
# Code: 16.59 -> Cat: 22
# Code: 16.63 -> Cat: 22
# Code: 16.81 -> Cat: 22
# Code: 16.82 -> Cat: 22
# Code: 160.2 -> Cat: 1
# Code: 160.3 -> Cat: 1
# Code: 160.8 -> Cat: 1
# Code: 160.9 -> Cat: 1
# Code: 161.0 -> Cat: 1
# Code: 161.1 -> Cat: 1
# Code: 161.2 -> Cat: 1
# Code: 161.3 -> Cat: 1
# Code: 161.8 -> Cat: 1
# Code: 161.9 -> Cat: 1
# Code: 162.0 -> Cat: 1
# Code: 162.2 -> Cat: 1
# Code: 162.3 -> Cat: 1
# Code: 162.4 -> Cat: 1
# Code: 162.5 -> Cat: 1
# Code: 162.8 -> Cat: 1
# Code: 162.9 -> Cat: 1
# Code: 163.0 -> Cat: 1
# Code: 163.8 -> Cat: 1
# Code: 163.9 -> Cat: 1
# Code: 164.0 -> Cat: 1
# Code: 164.1 -> Cat: 1
# Code: 164.2 -> Cat: 1
# Code: 164.3 -> Cat: 1
# Code: 164.8 -> Cat: 1
# Code: 164.9 -> Cat: 1
# Code: 17 -> Cat: 23
# Code: 17.33 -> Cat: 23
# Code: 17.35 -> Cat: 23
# Code: 17.36 -> Cat: 23
# Code: 17.41 -> Cat: 23
# Code: 17.42 -> Cat: 23
# Code: 17.55 -> Cat: 23
# Code: 17.56 -> Cat: 23
# Code: 17.70 -> Cat: 23
# Code: 17.71 -> Cat: 23
# Code: 170.0 -> Cat: 1
# Code: 170.2 -> Cat: 1
# Code: 170.3 -> Cat: 1
# Code: 170.7 -> Cat: 1
# Code: 171.0 -> Cat: 1
# Code: 171.2 -> Cat: 1
# Code: 171.3 -> Cat: 1
# Code: 171.4 -> Cat: 1
# Code: 171.5 -> Cat: 1
# Code: 171.6 -> Cat: 1
# Code: 171.7 -> Cat: 1
# Code: 171.8 -> Cat: 1
# Code: 172.0 -> Cat: 1
# Code: 172.3 -> Cat: 1
# Code: 172.4 -> Cat: 1
# Code: 172.5 -> Cat: 1
# Code: 172.6 -> Cat: 1
# Code: 172.7 -> Cat: 1
# Code: 172.8 -> Cat: 1
# Code: 172.9 -> Cat: 1
# Code: 173.0 -> Cat: 1
# Code: 173.1 -> Cat: 1
# Code: 173.2 -> Cat: 1
# Code: 173.22 -> Cat: 1
# Code: 173.3 -> Cat: 1
# Code: 173.31 -> Cat: 1
# Code: 173.32 -> Cat: 1
# Code: 173.4 -> Cat: 1
# Code: 173.41 -> Cat: 1
# Code: 173.42 -> Cat: 1
# Code: 173.5 -> Cat: 1
# Code: 173.6 -> Cat: 1
# Code: 173.7 -> Cat: 1
# Code: 173.72 -> Cat: 1
# Code: 173.8 -> Cat: 1
# Code: 173.9 -> Cat: 1
# Code: 174.3 -> Cat: 1
# Code: 174.4 -> Cat: 1
# Code: 174.5 -> Cat: 1
# Code: 174.8 -> Cat: 1
# Code: 174.9 -> Cat: 1
# Code: 175.9 -> Cat: 1
# Code: 176.0 -> Cat: 1
# Code: 176.1 -> Cat: 1
# Code: 176.3 -> Cat: 1
# Code: 176.4 -> Cat: 1
# Code: 176.5 -> Cat: 1
# Code: 176.8 -> Cat: 1
# Code: 176.9 -> Cat: 1
# Code: 179 -> Cat: 1
# Code: 18 -> Cat: 24
# Code: 18.09 -> Cat: 24
# Code: 18.11 -> Cat: 24
# Code: 18.12 -> Cat: 24
# Code: 18.21 -> Cat: 24
# Code: 18.29 -> Cat: 24
# Code: 18.39 -> Cat: 24
# Code: 18.4 -> Cat: 24
# Code: 18.79 -> Cat: 24
# Code: 180.0 -> Cat: 1
# Code: 180.8 -> Cat: 1
# Code: 180.9 -> Cat: 1
# Code: 182.0 -> Cat: 1
# Code: 183.0 -> Cat: 1
# Code: 183.2 -> Cat: 1
# Code: 183.8 -> Cat: 1
# Code: 184.0 -> Cat: 1
# Code: 184.4 -> Cat: 1
# Code: 184.8 -> Cat: 1
# Code: 185 -> Cat: 1
# Code: 186.9 -> Cat: 1
# Code: 187.4 -> Cat: 1
# Code: 188.0 -> Cat: 1
# Code: 188.1 -> Cat: 1
# Code: 188.2 -> Cat: 1
# Code: 188.3 -> Cat: 1
# Code: 188.4 -> Cat: 1
# Code: 188.5 -> Cat: 1
# Code: 188.8 -> Cat: 1
# Code: 188.9 -> Cat: 1
# Code: 189.0 -> Cat: 1
# Code: 189.1 -> Cat: 1
# Code: 189.2 -> Cat: 1
# Code: 189.3 -> Cat: 1
# Code: 189.8 -> Cat: 1
# Code: 19.9 -> Cat: 24
# Code: 190.5 -> Cat: 1
# Code: 190.6 -> Cat: 1
# Code: 191.0 -> Cat: 1
# Code: 191.1 -> Cat: 1
# Code: 191.2 -> Cat: 1
# Code: 191.3 -> Cat: 1
# Code: 191.4 -> Cat: 1
# Code: 191.5 -> Cat: 1
# Code: 191.6 -> Cat: 1
# Code: 191.7 -> Cat: 1
# Code: 191.8 -> Cat: 1
# Code: 191.9 -> Cat: 1
# Code: 192.0 -> Cat: 1
# Code: 192.1 -> Cat: 1
# Code: 192.2 -> Cat: 1
# Code: 193 -> Cat: 1
# Code: 194.0 -> Cat: 1
# Code: 194.1 -> Cat: 1
# Code: 194.3 -> Cat: 1
# Code: 194.5 -> Cat: 1
# Code: 195.0 -> Cat: 1
# Code: 195.1 -> Cat: 1
# Code: 195.2 -> Cat: 1
# Code: 195.3 -> Cat: 1
# Code: 195.8 -> Cat: 1
# Code: 196.0 -> Cat: 1
# Code: 196.1 -> Cat: 1
# Code: 196.2 -> Cat: 1
# Code: 196.3 -> Cat: 1
# Code: 196.5 -> Cat: 1
# Code: 196.6 -> Cat: 1
# Code: 196.8 -> Cat: 1
# Code: 196.9 -> Cat: 1
# Code: 197.0 -> Cat: 1
# Code: 197.1 -> Cat: 1
# Code: 197.2 -> Cat: 1
# Code: 197.3 -> Cat: 1
# Code: 197.4 -> Cat: 1
# Code: 197.5 -> Cat: 1
# Code: 197.6 -> Cat: 1
# Code: 197.7 -> Cat: 1
# Code: 197.8 -> Cat: 1
# Code: 198.0 -> Cat: 1
# Code: 198.1 -> Cat: 1
# Code: 198.2 -> Cat: 1
# Code: 198.3 -> Cat: 1
# Code: 198.4 -> Cat: 1
# Code: 198.5 -> Cat: 1
# Code: 198.6 -> Cat: 1
# Code: 198.7 -> Cat: 1
# Code: 198.81 -> Cat: 1
# Code: 198.82 -> Cat: 1
# Code: 198.89 -> Cat: 1
# Code: 199.0 -> Cat: 1
# Code: 199.1 -> Cat: 1
# Code: 20.01 -> Cat: 24
# Code: 20.09 -> Cat: 24
# Code: 20.2 -> Cat: 24
# Code: 20.3 -> Cat: 24
# Code: 20.4 -> Cat: 24
# Code: 20.41 -> Cat: 24
# Code: 20.49 -> Cat: 24
# Code: 20.5 -> Cat: 24
# Code: 20.59 -> Cat: 24
# Code: 20.6 -> Cat: 24
# Code: 20.61 -> Cat: 24
# Code: 20.7 -> Cat: 24
# Code: 200.00 -> Cat: 1
# Code: 200.01 -> Cat: 1
# Code: 200.02 -> Cat: 1
# Code: 200.03 -> Cat: 1
# Code: 200.05 -> Cat: 1
# Code: 200.08 -> Cat: 1
# Code: 200.10 -> Cat: 1
# Code: 200.11 -> Cat: 1
# Code: 200.18 -> Cat: 1
# Code: 200.20 -> Cat: 1
# Code: 200.21 -> Cat: 1
# Code: 200.22 -> Cat: 1
# Code: 200.23 -> Cat: 1
# Code: 200.24 -> Cat: 1
# Code: 200.28 -> Cat: 1
# Code: 200.30 -> Cat: 1
# Code: 200.33 -> Cat: 1
# Code: 200.37 -> Cat: 1
# Code: 200.40 -> Cat: 1
# Code: 200.42 -> Cat: 1
# Code: 200.47 -> Cat: 1
# Code: 200.48 -> Cat: 1
# Code: 200.50 -> Cat: 1
# Code: 200.60 -> Cat: 1
# Code: 200.70 -> Cat: 1
# Code: 200.71 -> Cat: 1
# Code: 200.78 -> Cat: 1
# Code: 200.80 -> Cat: 1
# Code: 201.48 -> Cat: 1
# Code: 201.50 -> Cat: 1
# Code: 201.52 -> Cat: 1
# Code: 201.58 -> Cat: 1
# Code: 201.90 -> Cat: 1
# Code: 201.91 -> Cat: 1
# Code: 201.92 -> Cat: 1
# Code: 201.98 -> Cat: 1
# Code: 202.00 -> Cat: 1
# Code: 202.01 -> Cat: 1
# Code: 202.03 -> Cat: 1
# Code: 202.05 -> Cat: 1
# Code: 202.06 -> Cat: 1
# Code: 202.08 -> Cat: 1
# Code: 202.10 -> Cat: 1
# Code: 202.11 -> Cat: 1
# Code: 202.12 -> Cat: 1
# Code: 202.13 -> Cat: 1
# Code: 202.18 -> Cat: 1
# Code: 202.20 -> Cat: 1
# Code: 202.40 -> Cat: 1
# Code: 202.43 -> Cat: 1
# Code: 202.52 -> Cat: 1
# Code: 202.60 -> Cat: 1
# Code: 202.70 -> Cat: 1
# Code: 202.78 -> Cat: 1
# Code: 202.80 -> Cat: 1
# Code: 202.81 -> Cat: 1
# Code: 202.82 -> Cat: 1
# Code: 202.83 -> Cat: 1
# Code: 202.85 -> Cat: 1
# Code: 202.87 -> Cat: 1
# Code: 202.88 -> Cat: 1
# Code: 202.90 -> Cat: 1
# Code: 203.00 -> Cat: 1
# Code: 203.01 -> Cat: 1
# Code: 203.02 -> Cat: 1
# Code: 203.10 -> Cat: 1
# Code: 203.12 -> Cat: 1
# Code: 203.80 -> Cat: 1
# Code: 203.82 -> Cat: 1
# Code: 204.00 -> Cat: 1
# Code: 204.01 -> Cat: 1
# Code: 204.02 -> Cat: 1
# Code: 204.10 -> Cat: 1
# Code: 204.11 -> Cat: 1
# Code: 204.12 -> Cat: 1
# Code: 204.80 -> Cat: 1
# Code: 204.90 -> Cat: 1
# Code: 205.00 -> Cat: 1
# Code: 205.01 -> Cat: 1
# Code: 205.02 -> Cat: 1
# Code: 205.10 -> Cat: 1
# Code: 205.11 -> Cat: 1
# Code: 205.12 -> Cat: 1
# Code: 205.30 -> Cat: 1
# Code: 205.90 -> Cat: 1
# Code: 206.00 -> Cat: 1
# Code: 207.22 -> Cat: 1
# Code: 207.80 -> Cat: 1
# Code: 208.00 -> Cat: 1
# Code: 208.90 -> Cat: 1
# Code: 208.91 -> Cat: 1
# Code: 209.03 -> Cat: 1
# Code: 209.17 -> Cat: 1
# Code: 209.20 -> Cat: 1
# Code: 209.21 -> Cat: 1
# Code: 209.25 -> Cat: 1
# Code: 209.29 -> Cat: 1
# Code: 209.30 -> Cat: 1
# Code: 209.36 -> Cat: 1
# Code: 209.43 -> Cat: 1
# Code: 209.51 -> Cat: 1
# Code: 209.57 -> Cat: 1
# Code: 209.61 -> Cat: 1
# Code: 209.63 -> Cat: 1
# Code: 209.69 -> Cat: 1
# Code: 209.71 -> Cat: 1
# Code: 209.72 -> Cat: 1
# Code: 209.73 -> Cat: 1
# Code: 209.74 -> Cat: 1
# Code: 209.75 -> Cat: 1
# Code: 209.79 -> Cat: 1
# Code: 21 -> Cat: 25
# Code: 21.00 -> Cat: 25
# Code: 21.01 -> Cat: 25
# Code: 21.02 -> Cat: 25
# Code: 21.03 -> Cat: 25
# Code: 21.09 -> Cat: 25
# Code: 21.1 -> Cat: 25
# Code: 21.2 -> Cat: 25
# Code: 21.21 -> Cat: 25
# Code: 21.22 -> Cat: 25
# Code: 21.30 -> Cat: 25
# Code: 21.32 -> Cat: 25
# Code: 21.4 -> Cat: 25
# Code: 21.5 -> Cat: 25
# Code: 21.61 -> Cat: 25
# Code: 21.62 -> Cat: 25
# Code: 21.69 -> Cat: 25
# Code: 21.71 -> Cat: 25
# Code: 21.72 -> Cat: 25
# Code: 21.81 -> Cat: 25
# Code: 21.83 -> Cat: 25
# Code: 21.86 -> Cat: 25
# Code: 21.88 -> Cat: 25
# Code: 21.89 -> Cat: 25
# Code: 210.1 -> Cat: 1
# Code: 210.2 -> Cat: 1
# Code: 210.4 -> Cat: 1
# Code: 211.0 -> Cat: 1
# Code: 211.1 -> Cat: 1
# Code: 211.2 -> Cat: 1
# Code: 211.3 -> Cat: 1
# Code: 211.4 -> Cat: 1
# Code: 211.5 -> Cat: 1
# Code: 211.6 -> Cat: 1
# Code: 211.7 -> Cat: 1
# Code: 211.8 -> Cat: 1
# Code: 211.9 -> Cat: 1
# Code: 212.0 -> Cat: 1
# Code: 212.1 -> Cat: 1
# Code: 212.2 -> Cat: 1
# Code: 212.3 -> Cat: 1
# Code: 212.5 -> Cat: 1
# Code: 212.6 -> Cat: 1
# Code: 212.7 -> Cat: 1
# Code: 213.0 -> Cat: 1
# Code: 213.2 -> Cat: 1
# Code: 213.7 -> Cat: 1
# Code: 214.0 -> Cat: 1
# Code: 214.1 -> Cat: 1
# Code: 214.2 -> Cat: 1
# Code: 214.3 -> Cat: 1
# Code: 214.4 -> Cat: 1
# Code: 214.8 -> Cat: 1
# Code: 214.9 -> Cat: 1
# Code: 215.0 -> Cat: 1
# Code: 215.3 -> Cat: 1
# Code: 215.4 -> Cat: 1
# Code: 215.5 -> Cat: 1
# Code: 215.6 -> Cat: 1
# Code: 216.3 -> Cat: 1
# Code: 216.4 -> Cat: 1
# Code: 216.5 -> Cat: 1
# Code: 216.6 -> Cat: 1
# Code: 216.7 -> Cat: 1
# Code: 216.9 -> Cat: 1
# Code: 217 -> Cat: 1
# Code: 218.0 -> Cat: 1
# Code: 218.1 -> Cat: 1
# Code: 218.2 -> Cat: 1
# Code: 218.9 -> Cat: 1
# Code: 219.1 -> Cat: 1
# Code: 22 -> Cat: 25
# Code: 22.01 -> Cat: 25
# Code: 22.1 -> Cat: 25
# Code: 22.11 -> Cat: 25
# Code: 22.19 -> Cat: 25
# Code: 22.2 -> Cat: 25
# Code: 22.41 -> Cat: 25
# Code: 22.42 -> Cat: 25
# Code: 22.50 -> Cat: 25
# Code: 22.52 -> Cat: 25
# Code: 22.60 -> Cat: 25
# Code: 22.62 -> Cat: 25
# Code: 22.63 -> Cat: 25
# Code: 22.64 -> Cat: 25
# Code: 22.79 -> Cat: 25
# Code: 22.9 -> Cat: 25
# Code: 220 -> Cat: 1
# Code: 221.0 -> Cat: 1
# Code: 221.8 -> Cat: 1
# Code: 223.0 -> Cat: 1
# Code: 225.0 -> Cat: 1
# Code: 225.1 -> Cat: 1
# Code: 225.2 -> Cat: 1
# Code: 225.3 -> Cat: 1
# Code: 225.4 -> Cat: 1
# Code: 226 -> Cat: 1
# Code: 227.0 -> Cat: 1
# Code: 227.1 -> Cat: 1
# Code: 227.3 -> Cat: 1
# Code: 228.01 -> Cat: 1
# Code: 228.02 -> Cat: 1
# Code: 228.04 -> Cat: 1
# Code: 228.09 -> Cat: 1
# Code: 228.1 -> Cat: 1
# Code: 229.8 -> Cat: 1
# Code: 23 -> Cat: 25
# Code: 23.01 -> Cat: 25
# Code: 23.09 -> Cat: 25
# Code: 23.1 -> Cat: 25
# Code: 23.11 -> Cat: 25
# Code: 23.19 -> Cat: 25
# Code: 23.3 -> Cat: 25
# Code: 23.4 -> Cat: 25
# Code: 23.73 -> Cat: 25
# Code: 23.9 -> Cat: 25
# Code: 230.0 -> Cat: 1
# Code: 230.1 -> Cat: 1
# Code: 230.2 -> Cat: 1
# Code: 230.6 -> Cat: 1
# Code: 230.8 -> Cat: 1
# Code: 230.9 -> Cat: 1
# Code: 231.2 -> Cat: 1
# Code: 232.5 -> Cat: 1
# Code: 232.9 -> Cat: 1
# Code: 233.0 -> Cat: 1
# Code: 233.1 -> Cat: 1
# Code: 233.3 -> Cat: 1
# Code: 233.31 -> Cat: 1
# Code: 233.4 -> Cat: 1
# Code: 233.7 -> Cat: 1
# Code: 233.9 -> Cat: 1
# Code: 235.2 -> Cat: 1
# Code: 235.3 -> Cat: 1
# Code: 235.4 -> Cat: 1
# Code: 235.5 -> Cat: 1
# Code: 235.6 -> Cat: 1
# Code: 235.7 -> Cat: 1
# Code: 235.8 -> Cat: 1
# Code: 236.0 -> Cat: 1
# Code: 236.2 -> Cat: 1
# Code: 236.7 -> Cat: 1
# Code: 236.91 -> Cat: 1
# Code: 237.0 -> Cat: 1
# Code: 237.1 -> Cat: 1
# Code: 237.3 -> Cat: 1
# Code: 237.5 -> Cat: 1
# Code: 237.6 -> Cat: 1
# Code: 237.70 -> Cat: 1
# Code: 237.71 -> Cat: 1
# Code: 237.72 -> Cat: 1
# Code: 237.73 -> Cat: 1
# Code: 237.9 -> Cat: 1
# Code: 238.0 -> Cat: 1
# Code: 238.1 -> Cat: 1
# Code: 238.2 -> Cat: 1
# Code: 238.4 -> Cat: 1
# Code: 238.6 -> Cat: 1
# Code: 238.7 -> Cat: 1
# Code: 238.71 -> Cat: 1
# Code: 238.72 -> Cat: 1
# Code: 238.73 -> Cat: 1
# Code: 238.74 -> Cat: 1
# Code: 238.75 -> Cat: 1
# Code: 238.76 -> Cat: 1
# Code: 238.77 -> Cat: 1
# Code: 238.79 -> Cat: 1
# Code: 238.8 -> Cat: 1
# Code: 239.0 -> Cat: 1
# Code: 239.1 -> Cat: 1
# Code: 239.2 -> Cat: 1
# Code: 239.4 -> Cat: 1
# Code: 239.5 -> Cat: 1
# Code: 239.6 -> Cat: 1
# Code: 239.7 -> Cat: 1
# Code: 239.89 -> Cat: 1
# Code: 24 -> Cat: 25
# Code: 24.0 -> Cat: 25
# Code: 24.11 -> Cat: 25
# Code: 24.2 -> Cat: 25
# Code: 24.3 -> Cat: 25
# Code: 24.32 -> Cat: 25
# Code: 24.4 -> Cat: 25
# Code: 24.5 -> Cat: 25
# Code: 24.7 -> Cat: 25
# Code: 240.9 -> Cat: 2
# Code: 241.0 -> Cat: 2
# Code: 241.1 -> Cat: 2
# Code: 241.9 -> Cat: 2
# Code: 242.00 -> Cat: 2
# Code: 242.01 -> Cat: 2
# Code: 242.10 -> Cat: 2
# Code: 242.20 -> Cat: 2
# Code: 242.21 -> Cat: 2
# Code: 242.30 -> Cat: 2
# Code: 242.80 -> Cat: 2
# Code: 242.81 -> Cat: 2
# Code: 242.90 -> Cat: 2
# Code: 242.91 -> Cat: 2
# Code: 243 -> Cat: 2
# Code: 244.0 -> Cat: 2
# Code: 244.1 -> Cat: 2
# Code: 244.2 -> Cat: 2
# Code: 244.3 -> Cat: 2
# Code: 244.8 -> Cat: 2
# Code: 244.9 -> Cat: 2
# Code: 245.2 -> Cat: 2
# Code: 245.4 -> Cat: 2
# Code: 245.8 -> Cat: 2
# Code: 245.9 -> Cat: 2
# Code: 246.2 -> Cat: 2
# Code: 246.8 -> Cat: 2
# Code: 246.9 -> Cat: 2
# Code: 249.00 -> Cat: 2
# Code: 249.01 -> Cat: 2
# Code: 249.11 -> Cat: 2
# Code: 249.50 -> Cat: 2
# Code: 249.60 -> Cat: 2
# Code: 249.80 -> Cat: 2
# Code: 249.81 -> Cat: 2
# Code: 249.90 -> Cat: 2
# Code: 249.91 -> Cat: 2
# Code: 25.01 -> Cat: 25
# Code: 25.02 -> Cat: 25
# Code: 25.1 -> Cat: 25
# Code: 25.2 -> Cat: 25
# Code: 25.3 -> Cat: 25
# Code: 25.51 -> Cat: 25
# Code: 25.59 -> Cat: 25
# Code: 25.92 -> Cat: 25
# Code: 250.00 -> Cat: 2
# Code: 250.01 -> Cat: 2
# Code: 250.02 -> Cat: 2
# Code: 250.03 -> Cat: 2
# Code: 250.10 -> Cat: 2
# Code: 250.11 -> Cat: 2
# Code: 250.12 -> Cat: 2
# Code: 250.13 -> Cat: 2
# Code: 250.20 -> Cat: 2
# Code: 250.21 -> Cat: 2
# Code: 250.22 -> Cat: 2
# Code: 250.23 -> Cat: 2
# Code: 250.30 -> Cat: 2
# Code: 250.31 -> Cat: 2
# Code: 250.32 -> Cat: 2
# Code: 250.33 -> Cat: 2
# Code: 250.40 -> Cat: 2
# Code: 250.41 -> Cat: 2
# Code: 250.42 -> Cat: 2
# Code: 250.43 -> Cat: 2
# Code: 250.50 -> Cat: 2
# Code: 250.51 -> Cat: 2
# Code: 250.52 -> Cat: 2
# Code: 250.53 -> Cat: 2
# Code: 250.60 -> Cat: 2
# Code: 250.61 -> Cat: 2
# Code: 250.62 -> Cat: 2
# Code: 250.63 -> Cat: 2
# Code: 250.70 -> Cat: 2
# Code: 250.71 -> Cat: 2
# Code: 250.72 -> Cat: 2
# Code: 250.73 -> Cat: 2
# Code: 250.80 -> Cat: 2
# Code: 250.81 -> Cat: 2
# Code: 250.82 -> Cat: 2
# Code: 250.83 -> Cat: 2
# Code: 250.90 -> Cat: 2
# Code: 250.91 -> Cat: 2
# Code: 250.92 -> Cat: 2
# Code: 250.93 -> Cat: 2
# Code: 251.0 -> Cat: 2
# Code: 251.1 -> Cat: 2
# Code: 251.2 -> Cat: 2
# Code: 251.3 -> Cat: 2
# Code: 251.5 -> Cat: 2
# Code: 251.8 -> Cat: 2
# Code: 251.9 -> Cat: 2
# Code: 252.0 -> Cat: 2
# Code: 252.00 -> Cat: 2
# Code: 252.01 -> Cat: 2
# Code: 252.02 -> Cat: 2
# Code: 252.08 -> Cat: 2
# Code: 252.1 -> Cat: 2
# Code: 252.8 -> Cat: 2
# Code: 253.0 -> Cat: 2
# Code: 253.1 -> Cat: 2
# Code: 253.2 -> Cat: 2
# Code: 253.3 -> Cat: 2
# Code: 253.4 -> Cat: 2
# Code: 253.5 -> Cat: 2
# Code: 253.6 -> Cat: 2
# Code: 253.7 -> Cat: 2
# Code: 253.8 -> Cat: 2
# Code: 253.9 -> Cat: 2
# Code: 254.0 -> Cat: 2
# Code: 254.1 -> Cat: 2
# Code: 254.8 -> Cat: 2
# Code: 255.0 -> Cat: 2
# Code: 255.10 -> Cat: 2
# Code: 255.12 -> Cat: 2
# Code: 255.2 -> Cat: 2
# Code: 255.3 -> Cat: 2
# Code: 255.4 -> Cat: 2
# Code: 255.41 -> Cat: 2
# Code: 255.42 -> Cat: 2
# Code: 255.5 -> Cat: 2
# Code: 255.8 -> Cat: 2
# Code: 255.9 -> Cat: 2
# Code: 256.1 -> Cat: 2
# Code: 256.39 -> Cat: 2
# Code: 256.4 -> Cat: 2
# Code: 257.1 -> Cat: 2
# Code: 257.2 -> Cat: 2
# Code: 258.01 -> Cat: 2
# Code: 258.1 -> Cat: 2
# Code: 258.8 -> Cat: 2
# Code: 258.9 -> Cat: 2
# Code: 259.2 -> Cat: 2
# Code: 259.4 -> Cat: 2
# Code: 259.8 -> Cat: 2
# Code: 259.9 -> Cat: 2
# Code: 26.0 -> Cat: 25
# Code: 26.11 -> Cat: 25
# Code: 26.21 -> Cat: 25
# Code: 26.30 -> Cat: 25
# Code: 26.31 -> Cat: 25
# Code: 26.32 -> Cat: 25
# Code: 26.91 -> Cat: 25
# Code: 26.99 -> Cat: 25
# Code: 260 -> Cat: 2
# Code: 261 -> Cat: 2
# Code: 262 -> Cat: 2
# Code: 263.0 -> Cat: 2
# Code: 263.1 -> Cat: 2
# Code: 263.8 -> Cat: 2
# Code: 263.9 -> Cat: 2
# Code: 265.0 -> Cat: 2
# Code: 265.1 -> Cat: 2
# Code: 265.2 -> Cat: 2
# Code: 266.2 -> Cat: 2
# Code: 266.9 -> Cat: 2
# Code: 267 -> Cat: 2
# Code: 268.2 -> Cat: 2
# Code: 268.9 -> Cat: 2
# Code: 269.0 -> Cat: 2
# Code: 269.2 -> Cat: 2
# Code: 269.3 -> Cat: 2
# Code: 269.8 -> Cat: 2
# Code: 269.9 -> Cat: 2
# Code: 27.0 -> Cat: 25
# Code: 27.22 -> Cat: 25
# Code: 27.23 -> Cat: 25
# Code: 27.24 -> Cat: 25
# Code: 27.31 -> Cat: 25
# Code: 27.42 -> Cat: 25
# Code: 27.49 -> Cat: 25
# Code: 27.51 -> Cat: 25
# Code: 27.52 -> Cat: 25
# Code: 27.53 -> Cat: 25
# Code: 27.55 -> Cat: 25
# Code: 27.56 -> Cat: 25
# Code: 27.57 -> Cat: 25
# Code: 27.59 -> Cat: 25
# Code: 27.61 -> Cat: 25
# Code: 27.69 -> Cat: 25
# Code: 27.72 -> Cat: 25
# Code: 27.92 -> Cat: 25
# Code: 270.0 -> Cat: 2
# Code: 270.2 -> Cat: 2
# Code: 270.4 -> Cat: 2
# Code: 270.6 -> Cat: 2
# Code: 270.7 -> Cat: 2
# Code: 271.0 -> Cat: 2
# Code: 271.3 -> Cat: 2
# Code: 271.8 -> Cat: 2
# Code: 272.0 -> Cat: 2
# Code: 272.1 -> Cat: 2
# Code: 272.2 -> Cat: 2
# Code: 272.4 -> Cat: 2
# Code: 272.5 -> Cat: 2
# Code: 272.6 -> Cat: 2
# Code: 272.7 -> Cat: 2
# Code: 272.8 -> Cat: 2
# Code: 272.9 -> Cat: 2
# Code: 273.0 -> Cat: 2
# Code: 273.1 -> Cat: 2
# Code: 273.2 -> Cat: 2
# Code: 273.3 -> Cat: 2
# Code: 273.4 -> Cat: 2
# Code: 273.8 -> Cat: 2
# Code: 273.9 -> Cat: 2
# Code: 274.0 -> Cat: 2
# Code: 274.00 -> Cat: 2
# Code: 274.01 -> Cat: 2
# Code: 274.02 -> Cat: 2
# Code: 274.03 -> Cat: 2
# Code: 274.11 -> Cat: 2
# Code: 274.82 -> Cat: 2
# Code: 274.89 -> Cat: 2
# Code: 274.9 -> Cat: 2
# Code: 275.0 -> Cat: 2
# Code: 275.01 -> Cat: 2
# Code: 275.02 -> Cat: 2
# Code: 275.03 -> Cat: 2
# Code: 275.09 -> Cat: 2
# Code: 275.1 -> Cat: 2
# Code: 275.2 -> Cat: 2
# Code: 275.3 -> Cat: 2
# Code: 275.40 -> Cat: 2
# Code: 275.41 -> Cat: 2
# Code: 275.42 -> Cat: 2
# Code: 275.49 -> Cat: 2
# Code: 275.5 -> Cat: 2
# Code: 275.8 -> Cat: 2
# Code: 275.9 -> Cat: 2
# Code: 276.0 -> Cat: 2
# Code: 276.1 -> Cat: 2
# Code: 276.2 -> Cat: 2
# Code: 276.3 -> Cat: 2
# Code: 276.4 -> Cat: 2
# Code: 276.5 -> Cat: 2
# Code: 276.50 -> Cat: 2
# Code: 276.51 -> Cat: 2
# Code: 276.52 -> Cat: 2
# Code: 276.6 -> Cat: 2
# Code: 276.61 -> Cat: 2
# Code: 276.69 -> Cat: 2
# Code: 276.7 -> Cat: 2
# Code: 276.8 -> Cat: 2
# Code: 276.9 -> Cat: 2
# Code: 277.00 -> Cat: 2
# Code: 277.02 -> Cat: 2
# Code: 277.09 -> Cat: 2
# Code: 277.1 -> Cat: 2
# Code: 277.3 -> Cat: 2
# Code: 277.30 -> Cat: 2
# Code: 277.31 -> Cat: 2
# Code: 277.39 -> Cat: 2
# Code: 277.4 -> Cat: 2
# Code: 277.6 -> Cat: 2
# Code: 277.7 -> Cat: 2
# Code: 277.8 -> Cat: 2
# Code: 277.87 -> Cat: 2
# Code: 277.88 -> Cat: 2
# Code: 277.89 -> Cat: 2
# Code: 277.9 -> Cat: 2
# Code: 278.00 -> Cat: 2
# Code: 278.01 -> Cat: 2
# Code: 278.02 -> Cat: 2
# Code: 278.03 -> Cat: 2
# Code: 278.1 -> Cat: 2
# Code: 278.8 -> Cat: 2
# Code: 279.00 -> Cat: 2
# Code: 279.01 -> Cat: 2
# Code: 279.03 -> Cat: 2
# Code: 279.06 -> Cat: 2
# Code: 279.11 -> Cat: 2
# Code: 279.3 -> Cat: 2
# Code: 279.4 -> Cat: 2
# Code: 279.41 -> Cat: 2
# Code: 279.49 -> Cat: 2
# Code: 279.50 -> Cat: 2
# Code: 279.51 -> Cat: 2
# Code: 279.52 -> Cat: 2
# Code: 279.53 -> Cat: 2
# Code: 279.8 -> Cat: 2
# Code: 279.9 -> Cat: 2
# Code: 28 -> Cat: 25
# Code: 28.0 -> Cat: 25
# Code: 28.11 -> Cat: 25
# Code: 28.2 -> Cat: 25
# Code: 28.7 -> Cat: 25
# Code: 280.0 -> Cat: 3
# Code: 280.8 -> Cat: 3
# Code: 280.9 -> Cat: 3
# Code: 281.0 -> Cat: 3
# Code: 281.1 -> Cat: 3
# Code: 281.2 -> Cat: 3
# Code: 281.3 -> Cat: 3
# Code: 281.8 -> Cat: 3
# Code: 281.9 -> Cat: 3
# Code: 282.0 -> Cat: 3
# Code: 282.1 -> Cat: 3
# Code: 282.2 -> Cat: 3
# Code: 282.3 -> Cat: 3
# Code: 282.4 -> Cat: 3
# Code: 282.40 -> Cat: 3
# Code: 282.41 -> Cat: 3
# Code: 282.43 -> Cat: 3
# Code: 282.44 -> Cat: 3
# Code: 282.46 -> Cat: 3
# Code: 282.49 -> Cat: 3
# Code: 282.5 -> Cat: 3
# Code: 282.60 -> Cat: 3
# Code: 282.62 -> Cat: 3
# Code: 282.64 -> Cat: 3
# Code: 282.7 -> Cat: 3
# Code: 282.8 -> Cat: 3
# Code: 282.9 -> Cat: 3
# Code: 283.0 -> Cat: 3
# Code: 283.10 -> Cat: 3
# Code: 283.11 -> Cat: 3
# Code: 283.19 -> Cat: 3
# Code: 283.2 -> Cat: 3
# Code: 283.9 -> Cat: 3
# Code: 284.0 -> Cat: 3
# Code: 284.1 -> Cat: 3
# Code: 284.11 -> Cat: 3
# Code: 284.12 -> Cat: 3
# Code: 284.19 -> Cat: 3
# Code: 284.2 -> Cat: 3
# Code: 284.8 -> Cat: 3
# Code: 284.89 -> Cat: 3
# Code: 284.9 -> Cat: 3
# Code: 285.1 -> Cat: 3
# Code: 285.21 -> Cat: 3
# Code: 285.22 -> Cat: 3
# Code: 285.29 -> Cat: 3
# Code: 285.3 -> Cat: 3
# Code: 285.8 -> Cat: 3
# Code: 285.9 -> Cat: 3
# Code: 286.0 -> Cat: 3
# Code: 286.1 -> Cat: 3
# Code: 286.2 -> Cat: 3
# Code: 286.3 -> Cat: 3
# Code: 286.4 -> Cat: 3
# Code: 286.5 -> Cat: 3
# Code: 286.52 -> Cat: 3
# Code: 286.6 -> Cat: 3
# Code: 286.7 -> Cat: 3
# Code: 286.9 -> Cat: 3
# Code: 287.0 -> Cat: 3
# Code: 287.1 -> Cat: 3
# Code: 287.2 -> Cat: 3
# Code: 287.3 -> Cat: 3
# Code: 287.30 -> Cat: 3
# Code: 287.31 -> Cat: 3
# Code: 287.32 -> Cat: 3
# Code: 287.33 -> Cat: 3
# Code: 287.4 -> Cat: 3
# Code: 287.49 -> Cat: 3
# Code: 287.5 -> Cat: 3
# Code: 287.9 -> Cat: 3
# Code: 288.0 -> Cat: 3
# Code: 288.00 -> Cat: 3
# Code: 288.01 -> Cat: 3
# Code: 288.02 -> Cat: 3
# Code: 288.03 -> Cat: 3
# Code: 288.04 -> Cat: 3
# Code: 288.09 -> Cat: 3
# Code: 288.1 -> Cat: 3
# Code: 288.2 -> Cat: 3
# Code: 288.3 -> Cat: 3
# Code: 288.4 -> Cat: 3
# Code: 288.50 -> Cat: 3
# Code: 288.51 -> Cat: 3
# Code: 288.59 -> Cat: 3
# Code: 288.60 -> Cat: 3
# Code: 288.61 -> Cat: 3
# Code: 288.62 -> Cat: 3
# Code: 288.63 -> Cat: 3
# Code: 288.66 -> Cat: 3
# Code: 288.8 -> Cat: 3
# Code: 288.9 -> Cat: 3
# Code: 289.0 -> Cat: 3
# Code: 289.1 -> Cat: 3
# Code: 289.3 -> Cat: 3
# Code: 289.4 -> Cat: 3
# Code: 289.50 -> Cat: 3
# Code: 289.51 -> Cat: 3
# Code: 289.52 -> Cat: 3
# Code: 289.59 -> Cat: 3
# Code: 289.7 -> Cat: 3
# Code: 289.8 -> Cat: 3
# Code: 289.81 -> Cat: 3
# Code: 289.82 -> Cat: 3
# Code: 289.83 -> Cat: 3
# Code: 289.84 -> Cat: 3
# Code: 289.89 -> Cat: 3
# Code: 289.9 -> Cat: 3
# Code: 29.0 -> Cat: 25
# Code: 29.1 -> Cat: 25
# Code: 29.11 -> Cat: 25
# Code: 29.12 -> Cat: 25
# Code: 29.2 -> Cat: 25
# Code: 29.3 -> Cat: 25
# Code: 29.31 -> Cat: 25
# Code: 29.32 -> Cat: 25
# Code: 29.33 -> Cat: 25
# Code: 29.39 -> Cat: 25
# Code: 29.4 -> Cat: 25
# Code: 29.5 -> Cat: 25
# Code: 29.51 -> Cat: 25
# Code: 29.59 -> Cat: 25
# Code: 29.6 -> Cat: 25
# Code: 29.9 -> Cat: 25
# Code: 290.0 -> Cat: 4
# Code: 290.10 -> Cat: 4
# Code: 290.12 -> Cat: 4
# Code: 290.3 -> Cat: 4
# Code: 290.40 -> Cat: 4
# Code: 290.41 -> Cat: 4
# Code: 290.42 -> Cat: 4
# Code: 290.43 -> Cat: 4
# Code: 291.0 -> Cat: 4
# Code: 291.1 -> Cat: 4
# Code: 291.2 -> Cat: 4
# Code: 291.3 -> Cat: 4
# Code: 291.81 -> Cat: 4
# Code: 291.89 -> Cat: 4
# Code: 292.0 -> Cat: 4
# Code: 292.11 -> Cat: 4
# Code: 292.12 -> Cat: 4
# Code: 292.81 -> Cat: 4
# Code: 292.82 -> Cat: 4
# Code: 292.84 -> Cat: 4
# Code: 292.85 -> Cat: 4
# Code: 292.89 -> Cat: 4
# Code: 292.9 -> Cat: 4
# Code: 293.0 -> Cat: 4
# Code: 293.1 -> Cat: 4
# Code: 293.81 -> Cat: 4
# Code: 293.82 -> Cat: 4
# Code: 293.83 -> Cat: 4
# Code: 293.84 -> Cat: 4
# Code: 293.89 -> Cat: 4
# Code: 293.9 -> Cat: 4
# Code: 294.0 -> Cat: 4
# Code: 294.10 -> Cat: 4
# Code: 294.11 -> Cat: 4
# Code: 294.20 -> Cat: 4
# Code: 294.21 -> Cat: 4
# Code: 294.8 -> Cat: 4
# Code: 294.9 -> Cat: 4
# Code: 295.02 -> Cat: 4
# Code: 295.12 -> Cat: 4
# Code: 295.20 -> Cat: 4
# Code: 295.22 -> Cat: 4
# Code: 295.24 -> Cat: 4
# Code: 295.30 -> Cat: 4
# Code: 295.32 -> Cat: 4
# Code: 295.40 -> Cat: 4
# Code: 295.44 -> Cat: 4
# Code: 295.60 -> Cat: 4
# Code: 295.62 -> Cat: 4
# Code: 295.64 -> Cat: 4
# Code: 295.70 -> Cat: 4
# Code: 295.72 -> Cat: 4
# Code: 295.73 -> Cat: 4
# Code: 295.74 -> Cat: 4
# Code: 295.75 -> Cat: 4
# Code: 295.80 -> Cat: 4
# Code: 295.90 -> Cat: 4
# Code: 295.92 -> Cat: 4
# Code: 296.00 -> Cat: 4
# Code: 296.04 -> Cat: 4
# Code: 296.14 -> Cat: 4
# Code: 296.20 -> Cat: 4
# Code: 296.21 -> Cat: 4
# Code: 296.22 -> Cat: 4
# Code: 296.23 -> Cat: 4
# Code: 296.24 -> Cat: 4
# Code: 296.25 -> Cat: 4
# Code: 296.30 -> Cat: 4
# Code: 296.31 -> Cat: 4
# Code: 296.32 -> Cat: 4
# Code: 296.33 -> Cat: 4
# Code: 296.34 -> Cat: 4
# Code: 296.40 -> Cat: 4
# Code: 296.44 -> Cat: 4
# Code: 296.50 -> Cat: 4
# Code: 296.51 -> Cat: 4
# Code: 296.53 -> Cat: 4
# Code: 296.54 -> Cat: 4
# Code: 296.7 -> Cat: 4
# Code: 296.80 -> Cat: 4
# Code: 296.81 -> Cat: 4
# Code: 296.89 -> Cat: 4
# Code: 296.90 -> Cat: 4
# Code: 296.99 -> Cat: 4
# Code: 297.1 -> Cat: 4
# Code: 297.2 -> Cat: 4
# Code: 297.8 -> Cat: 4
# Code: 297.9 -> Cat: 4
# Code: 298.0 -> Cat: 4
# Code: 298.2 -> Cat: 4
# Code: 298.4 -> Cat: 4
# Code: 298.9 -> Cat: 4
# Code: 299.00 -> Cat: 4
# Code: 299.80 -> Cat: 4
# Code: 299.90 -> Cat: 4
# Code: 30.09 -> Cat: 26
# Code: 30.2 -> Cat: 26
# Code: 30.29 -> Cat: 26
# Code: 30.3 -> Cat: 26
# Code: 30.4 -> Cat: 26
# Code: 30.9 -> Cat: 26
# Code: 300.00 -> Cat: 4
# Code: 300.01 -> Cat: 4
# Code: 300.02 -> Cat: 4
# Code: 300.09 -> Cat: 4
# Code: 300.11 -> Cat: 4
# Code: 300.12 -> Cat: 4
# Code: 300.14 -> Cat: 4
# Code: 300.15 -> Cat: 4
# Code: 300.16 -> Cat: 4
# Code: 300.21 -> Cat: 4
# Code: 300.22 -> Cat: 4
# Code: 300.29 -> Cat: 4
# Code: 300.3 -> Cat: 4
# Code: 300.4 -> Cat: 4
# Code: 300.7 -> Cat: 4
# Code: 300.89 -> Cat: 4
# Code: 300.9 -> Cat: 4
# Code: 301.0 -> Cat: 4
# Code: 301.13 -> Cat: 4
# Code: 301.20 -> Cat: 4
# Code: 301.22 -> Cat: 4
# Code: 301.3 -> Cat: 4
# Code: 301.4 -> Cat: 4
# Code: 301.50 -> Cat: 4
# Code: 301.51 -> Cat: 4
# Code: 301.7 -> Cat: 4
# Code: 301.81 -> Cat: 4
# Code: 301.83 -> Cat: 4
# Code: 301.9 -> Cat: 4
# Code: 302.50 -> Cat: 4
# Code: 302.85 -> Cat: 4
# Code: 302.9 -> Cat: 4
# Code: 303.00 -> Cat: 4
# Code: 303.01 -> Cat: 4
# Code: 303.02 -> Cat: 4
# Code: 303.03 -> Cat: 4
# Code: 303.90 -> Cat: 4
# Code: 303.91 -> Cat: 4
# Code: 303.92 -> Cat: 4
# Code: 303.93 -> Cat: 4
# Code: 304.00 -> Cat: 4
# Code: 304.01 -> Cat: 4
# Code: 304.02 -> Cat: 4
# Code: 304.03 -> Cat: 4
# Code: 304.10 -> Cat: 4
# Code: 304.11 -> Cat: 4
# Code: 304.20 -> Cat: 4
# Code: 304.21 -> Cat: 4
# Code: 304.22 -> Cat: 4
# Code: 304.23 -> Cat: 4
# Code: 304.30 -> Cat: 4
# Code: 304.31 -> Cat: 4
# Code: 304.40 -> Cat: 4
# Code: 304.41 -> Cat: 4
# Code: 304.43 -> Cat: 4
# Code: 304.60 -> Cat: 4
# Code: 304.61 -> Cat: 4
# Code: 304.70 -> Cat: 4
# Code: 304.71 -> Cat: 4
# Code: 304.72 -> Cat: 4
# Code: 304.73 -> Cat: 4
# Code: 304.80 -> Cat: 4
# Code: 304.81 -> Cat: 4
# Code: 304.83 -> Cat: 4
# Code: 304.90 -> Cat: 4
# Code: 304.91 -> Cat: 4
# Code: 304.93 -> Cat: 4
# Code: 305.00 -> Cat: 4
# Code: 305.01 -> Cat: 4
# Code: 305.02 -> Cat: 4
# Code: 305.03 -> Cat: 4
# Code: 305.1 -> Cat: 4
# Code: 305.20 -> Cat: 4
# Code: 305.21 -> Cat: 4
# Code: 305.22 -> Cat: 4
# Code: 305.23 -> Cat: 4
# Code: 305.30 -> Cat: 4
# Code: 305.31 -> Cat: 4
# Code: 305.40 -> Cat: 4
# Code: 305.41 -> Cat: 4
# Code: 305.43 -> Cat: 4
# Code: 305.50 -> Cat: 4
# Code: 305.51 -> Cat: 4
# Code: 305.52 -> Cat: 4
# Code: 305.53 -> Cat: 4
# Code: 305.60 -> Cat: 4
# Code: 305.61 -> Cat: 4
# Code: 305.62 -> Cat: 4
# Code: 305.63 -> Cat: 4
# Code: 305.70 -> Cat: 4
# Code: 305.71 -> Cat: 4
# Code: 305.73 -> Cat: 4
# Code: 305.80 -> Cat: 4
# Code: 305.83 -> Cat: 4
# Code: 305.90 -> Cat: 4
# Code: 305.91 -> Cat: 4
# Code: 305.92 -> Cat: 4
# Code: 305.93 -> Cat: 4
# Code: 306.0 -> Cat: 4
# Code: 306.1 -> Cat: 4
# Code: 306.2 -> Cat: 4
# Code: 306.8 -> Cat: 4
# Code: 306.9 -> Cat: 4
# Code: 307.1 -> Cat: 4
# Code: 307.23 -> Cat: 4
# Code: 307.42 -> Cat: 4
# Code: 307.47 -> Cat: 4
# Code: 307.49 -> Cat: 4
# Code: 307.50 -> Cat: 4
# Code: 307.51 -> Cat: 4
# Code: 307.52 -> Cat: 4
# Code: 307.59 -> Cat: 4
# Code: 307.6 -> Cat: 4
# Code: 307.81 -> Cat: 4
# Code: 307.89 -> Cat: 4
# Code: 307.9 -> Cat: 4
# Code: 308.0 -> Cat: 4
# Code: 308.1 -> Cat: 4
# Code: 308.2 -> Cat: 4
# Code: 308.3 -> Cat: 4
# Code: 308.9 -> Cat: 4
# Code: 309.0 -> Cat: 4
# Code: 309.1 -> Cat: 4
# Code: 309.24 -> Cat: 4
# Code: 309.28 -> Cat: 4
# Code: 309.3 -> Cat: 4
# Code: 309.4 -> Cat: 4
# Code: 309.81 -> Cat: 4
# Code: 309.89 -> Cat: 4
# Code: 309.9 -> Cat: 4
# Code: 31 -> Cat: 26
# Code: 31.0 -> Cat: 26
# Code: 31.1 -> Cat: 26
# Code: 31.29 -> Cat: 26
# Code: 31.3 -> Cat: 26
# Code: 31.41 -> Cat: 26
# Code: 31.42 -> Cat: 26
# Code: 31.43 -> Cat: 26
# Code: 31.44 -> Cat: 26
# Code: 31.45 -> Cat: 26
# Code: 31.48 -> Cat: 26
# Code: 31.49 -> Cat: 26
# Code: 31.5 -> Cat: 26
# Code: 31.61 -> Cat: 26
# Code: 31.62 -> Cat: 26
# Code: 31.64 -> Cat: 26
# Code: 31.69 -> Cat: 26
# Code: 31.71 -> Cat: 26
# Code: 31.72 -> Cat: 26
# Code: 31.73 -> Cat: 26
# Code: 31.74 -> Cat: 26
# Code: 31.75 -> Cat: 26
# Code: 31.79 -> Cat: 26
# Code: 31.92 -> Cat: 26
# Code: 31.93 -> Cat: 26
# Code: 31.95 -> Cat: 26
# Code: 31.98 -> Cat: 26
# Code: 31.99 -> Cat: 26
# Code: 310.0 -> Cat: 4
# Code: 310.1 -> Cat: 4
# Code: 310.2 -> Cat: 4
# Code: 310.8 -> Cat: 4
# Code: 310.9 -> Cat: 4
# Code: 311 -> Cat: 4
# Code: 312.30 -> Cat: 4
# Code: 312.34 -> Cat: 4
# Code: 312.39 -> Cat: 4
# Code: 312.89 -> Cat: 4
# Code: 312.9 -> Cat: 4
# Code: 313.81 -> Cat: 4
# Code: 314.00 -> Cat: 4
# Code: 314.01 -> Cat: 4
# Code: 315.2 -> Cat: 4
# Code: 315.31 -> Cat: 4
# Code: 315.39 -> Cat: 4
# Code: 315.4 -> Cat: 4
# Code: 315.8 -> Cat: 4
# Code: 315.9 -> Cat: 4
# Code: 316 -> Cat: 4
# Code: 317 -> Cat: 4
# Code: 318.0 -> Cat: 4
# Code: 318.1 -> Cat: 4
# Code: 318.2 -> Cat: 4
# Code: 319 -> Cat: 4
# Code: 32 -> Cat: 26
# Code: 32.01 -> Cat: 26
# Code: 32.09 -> Cat: 26
# Code: 32.1 -> Cat: 26
# Code: 32.20 -> Cat: 26
# Code: 32.22 -> Cat: 26
# Code: 32.24 -> Cat: 26
# Code: 32.27 -> Cat: 26
# Code: 32.28 -> Cat: 26
# Code: 32.29 -> Cat: 26
# Code: 32.3 -> Cat: 26
# Code: 32.30 -> Cat: 26
# Code: 32.39 -> Cat: 26
# Code: 32.4 -> Cat: 26
# Code: 32.41 -> Cat: 26
# Code: 32.49 -> Cat: 26
# Code: 32.5 -> Cat: 26
# Code: 32.59 -> Cat: 26
# Code: 32.6 -> Cat: 26
# Code: 32.9 -> Cat: 26
# Code: 320.0 -> Cat: 5
# Code: 320.1 -> Cat: 5
# Code: 320.2 -> Cat: 5
# Code: 320.3 -> Cat: 5
# Code: 320.7 -> Cat: 5
# Code: 320.82 -> Cat: 5
# Code: 320.89 -> Cat: 5
# Code: 320.9 -> Cat: 5
# Code: 321.0 -> Cat: 5
# Code: 321.2 -> Cat: 5
# Code: 322.0 -> Cat: 5
# Code: 322.1 -> Cat: 5
# Code: 322.2 -> Cat: 5
# Code: 322.9 -> Cat: 5
# Code: 323.4 -> Cat: 5
# Code: 323.41 -> Cat: 5
# Code: 323.51 -> Cat: 5
# Code: 323.6 -> Cat: 5
# Code: 323.61 -> Cat: 5
# Code: 323.62 -> Cat: 5
# Code: 323.72 -> Cat: 5
# Code: 323.8 -> Cat: 5
# Code: 323.81 -> Cat: 5
# Code: 323.82 -> Cat: 5
# Code: 323.9 -> Cat: 5
# Code: 324.0 -> Cat: 5
# Code: 324.1 -> Cat: 5
# Code: 324.9 -> Cat: 5
# Code: 325 -> Cat: 5
# Code: 326 -> Cat: 5
# Code: 327.13 -> Cat: 5
# Code: 327.19 -> Cat: 5
# Code: 327.20 -> Cat: 5
# Code: 327.21 -> Cat: 5
# Code: 327.23 -> Cat: 5
# Code: 327.24 -> Cat: 5
# Code: 327.25 -> Cat: 5
# Code: 327.26 -> Cat: 5
# Code: 327.27 -> Cat: 5
# Code: 327.37 -> Cat: 5
# Code: 327.42 -> Cat: 5
# Code: 33 -> Cat: 26
# Code: 33.1 -> Cat: 26
# Code: 33.2 -> Cat: 26
# Code: 33.20 -> Cat: 26
# Code: 33.21 -> Cat: 26
# Code: 33.22 -> Cat: 26
# Code: 33.23 -> Cat: 26
# Code: 33.24 -> Cat: 26
# Code: 33.26 -> Cat: 26
# Code: 33.27 -> Cat: 26
# Code: 33.28 -> Cat: 26
# Code: 33.29 -> Cat: 26
# Code: 33.34 -> Cat: 26
# Code: 33.39 -> Cat: 26
# Code: 33.41 -> Cat: 26
# Code: 33.42 -> Cat: 26
# Code: 33.43 -> Cat: 26
# Code: 33.48 -> Cat: 26
# Code: 33.49 -> Cat: 26
# Code: 33.71 -> Cat: 26
# Code: 33.73 -> Cat: 26
# Code: 33.78 -> Cat: 26
# Code: 33.79 -> Cat: 26
# Code: 33.9 -> Cat: 26
# Code: 33.91 -> Cat: 26
# Code: 33.92 -> Cat: 26
# Code: 33.93 -> Cat: 26
# Code: 33.99 -> Cat: 26
# Code: 330.0 -> Cat: 5
# Code: 330.1 -> Cat: 5
# Code: 330.8 -> Cat: 5
# Code: 331.0 -> Cat: 5
# Code: 331.19 -> Cat: 5
# Code: 331.3 -> Cat: 5
# Code: 331.4 -> Cat: 5
# Code: 331.5 -> Cat: 5
# Code: 331.82 -> Cat: 5
# Code: 331.83 -> Cat: 5
# Code: 331.89 -> Cat: 5
# Code: 331.9 -> Cat: 5
# Code: 332.0 -> Cat: 5
# Code: 332.1 -> Cat: 5
# Code: 333.0 -> Cat: 5
# Code: 333.1 -> Cat: 5
# Code: 333.2 -> Cat: 5
# Code: 333.4 -> Cat: 5
# Code: 333.5 -> Cat: 5
# Code: 333.6 -> Cat: 5
# Code: 333.7 -> Cat: 5
# Code: 333.72 -> Cat: 5
# Code: 333.79 -> Cat: 5
# Code: 333.81 -> Cat: 5
# Code: 333.82 -> Cat: 5
# Code: 333.84 -> Cat: 5
# Code: 333.85 -> Cat: 5
# Code: 333.90 -> Cat: 5
# Code: 333.91 -> Cat: 5
# Code: 333.92 -> Cat: 5
# Code: 333.94 -> Cat: 5
# Code: 333.99 -> Cat: 5
# Code: 334.0 -> Cat: 5
# Code: 334.1 -> Cat: 5
# Code: 334.2 -> Cat: 5
# Code: 334.3 -> Cat: 5
# Code: 334.4 -> Cat: 5
# Code: 334.8 -> Cat: 5
# Code: 334.9 -> Cat: 5
# Code: 335.10 -> Cat: 5
# Code: 335.11 -> Cat: 5
# Code: 335.20 -> Cat: 5
# Code: 335.22 -> Cat: 5
# Code: 335.23 -> Cat: 5
# Code: 336.0 -> Cat: 5
# Code: 336.1 -> Cat: 5
# Code: 336.3 -> Cat: 5
# Code: 336.8 -> Cat: 5
# Code: 336.9 -> Cat: 5
# Code: 337.0 -> Cat: 5
# Code: 337.01 -> Cat: 5
# Code: 337.09 -> Cat: 5
# Code: 337.1 -> Cat: 5
# Code: 337.20 -> Cat: 5
# Code: 337.21 -> Cat: 5
# Code: 337.22 -> Cat: 5
# Code: 337.29 -> Cat: 5
# Code: 337.3 -> Cat: 5
# Code: 337.9 -> Cat: 5
# Code: 338.0 -> Cat: 5
# Code: 338.11 -> Cat: 5
# Code: 338.12 -> Cat: 5
# Code: 338.18 -> Cat: 5
# Code: 338.19 -> Cat: 5
# Code: 338.21 -> Cat: 5
# Code: 338.22 -> Cat: 5
# Code: 338.28 -> Cat: 5
# Code: 338.29 -> Cat: 5
# Code: 338.3 -> Cat: 5
# Code: 338.4 -> Cat: 5
# Code: 339.00 -> Cat: 5
# Code: 339.02 -> Cat: 5
# Code: 339.12 -> Cat: 5
# Code: 339.20 -> Cat: 5
# Code: 339.3 -> Cat: 5
# Code: 339.89 -> Cat: 5
# Code: 34 -> Cat: 26
# Code: 34.01 -> Cat: 26
# Code: 34.02 -> Cat: 26
# Code: 34.03 -> Cat: 26
# Code: 34.04 -> Cat: 26
# Code: 34.06 -> Cat: 26
# Code: 34.09 -> Cat: 26
# Code: 34.1 -> Cat: 26
# Code: 34.20 -> Cat: 26
# Code: 34.21 -> Cat: 26
# Code: 34.22 -> Cat: 26
# Code: 34.23 -> Cat: 26
# Code: 34.24 -> Cat: 26
# Code: 34.25 -> Cat: 26
# Code: 34.26 -> Cat: 26
# Code: 34.27 -> Cat: 26
# Code: 34.3 -> Cat: 26
# Code: 34.4 -> Cat: 26
# Code: 34.51 -> Cat: 26
# Code: 34.52 -> Cat: 26
# Code: 34.59 -> Cat: 26
# Code: 34.6 -> Cat: 26
# Code: 34.71 -> Cat: 26
# Code: 34.72 -> Cat: 26
# Code: 34.73 -> Cat: 26
# Code: 34.79 -> Cat: 26
# Code: 34.81 -> Cat: 26
# Code: 34.82 -> Cat: 26
# Code: 34.83 -> Cat: 26
# Code: 34.84 -> Cat: 26
# Code: 34.91 -> Cat: 26
# Code: 34.92 -> Cat: 26
# Code: 34.93 -> Cat: 26
# Code: 34.99 -> Cat: 26
# Code: 340 -> Cat: 5
# Code: 341.0 -> Cat: 5
# Code: 341.1 -> Cat: 5
# Code: 341.20 -> Cat: 5
# Code: 341.8 -> Cat: 5
# Code: 341.9 -> Cat: 5
# Code: 342.00 -> Cat: 5
# Code: 342.01 -> Cat: 5
# Code: 342.02 -> Cat: 5
# Code: 342.10 -> Cat: 5
# Code: 342.11 -> Cat: 5
# Code: 342.12 -> Cat: 5
# Code: 342.80 -> Cat: 5
# Code: 342.81 -> Cat: 5
# Code: 342.82 -> Cat: 5
# Code: 342.90 -> Cat: 5
# Code: 342.91 -> Cat: 5
# Code: 342.92 -> Cat: 5
# Code: 343.0 -> Cat: 5
# Code: 343.1 -> Cat: 5
# Code: 343.2 -> Cat: 5
# Code: 343.4 -> Cat: 5
# Code: 343.8 -> Cat: 5
# Code: 343.9 -> Cat: 5
# Code: 344.00 -> Cat: 5
# Code: 344.01 -> Cat: 5
# Code: 344.02 -> Cat: 5
# Code: 344.03 -> Cat: 5
# Code: 344.04 -> Cat: 5
# Code: 344.09 -> Cat: 5
# Code: 344.1 -> Cat: 5
# Code: 344.2 -> Cat: 5
# Code: 344.30 -> Cat: 5
# Code: 344.31 -> Cat: 5
# Code: 344.40 -> Cat: 5
# Code: 344.41 -> Cat: 5
# Code: 344.42 -> Cat: 5
# Code: 344.5 -> Cat: 5
# Code: 344.60 -> Cat: 5
# Code: 344.61 -> Cat: 5
# Code: 344.81 -> Cat: 5
# Code: 344.89 -> Cat: 5
# Code: 344.9 -> Cat: 5
# Code: 345.00 -> Cat: 5
# Code: 345.01 -> Cat: 5
# Code: 345.10 -> Cat: 5
# Code: 345.11 -> Cat: 5
# Code: 345.2 -> Cat: 5
# Code: 345.3 -> Cat: 5
# Code: 345.40 -> Cat: 5
# Code: 345.41 -> Cat: 5
# Code: 345.50 -> Cat: 5
# Code: 345.51 -> Cat: 5
# Code: 345.70 -> Cat: 5
# Code: 345.71 -> Cat: 5
# Code: 345.80 -> Cat: 5
# Code: 345.81 -> Cat: 5
# Code: 345.90 -> Cat: 5
# Code: 345.91 -> Cat: 5
# Code: 346.00 -> Cat: 5
# Code: 346.20 -> Cat: 5
# Code: 346.70 -> Cat: 5
# Code: 346.80 -> Cat: 5
# Code: 346.90 -> Cat: 5
# Code: 346.91 -> Cat: 5
# Code: 346.93 -> Cat: 5
# Code: 347.00 -> Cat: 5
# Code: 347.01 -> Cat: 5
# Code: 347.10 -> Cat: 5
# Code: 348.0 -> Cat: 5
# Code: 348.1 -> Cat: 5
# Code: 348.2 -> Cat: 5
# Code: 348.3 -> Cat: 5
# Code: 348.30 -> Cat: 5
# Code: 348.31 -> Cat: 5
# Code: 348.39 -> Cat: 5
# Code: 348.4 -> Cat: 5
# Code: 348.5 -> Cat: 5
# Code: 348.8 -> Cat: 5
# Code: 348.81 -> Cat: 5
# Code: 348.82 -> Cat: 5
# Code: 348.89 -> Cat: 5
# Code: 348.9 -> Cat: 5
# Code: 349.0 -> Cat: 5
# Code: 349.1 -> Cat: 5
# Code: 349.2 -> Cat: 5
# Code: 349.31 -> Cat: 5
# Code: 349.39 -> Cat: 5
# Code: 349.81 -> Cat: 5
# Code: 349.82 -> Cat: 5
# Code: 349.89 -> Cat: 5
# Code: 349.9 -> Cat: 5
# Code: 35.05 -> Cat: 27
# Code: 35.1 -> Cat: 27
# Code: 35.11 -> Cat: 27
# Code: 35.12 -> Cat: 27
# Code: 35.14 -> Cat: 27
# Code: 35.21 -> Cat: 27
# Code: 35.22 -> Cat: 27
# Code: 35.23 -> Cat: 27
# Code: 35.24 -> Cat: 27
# Code: 35.25 -> Cat: 27
# Code: 35.27 -> Cat: 27
# Code: 35.28 -> Cat: 27
# Code: 35.3 -> Cat: 27
# Code: 35.31 -> Cat: 27
# Code: 35.32 -> Cat: 27
# Code: 35.33 -> Cat: 27
# Code: 35.35 -> Cat: 27
# Code: 35.39 -> Cat: 27
# Code: 35.41 -> Cat: 27
# Code: 35.42 -> Cat: 27
# Code: 35.50 -> Cat: 27
# Code: 35.51 -> Cat: 27
# Code: 35.52 -> Cat: 27
# Code: 35.53 -> Cat: 27
# Code: 35.55 -> Cat: 27
# Code: 35.61 -> Cat: 27
# Code: 35.62 -> Cat: 27
# Code: 35.70 -> Cat: 27
# Code: 35.71 -> Cat: 27
# Code: 35.72 -> Cat: 27
# Code: 35.82 -> Cat: 27
# Code: 35.9 -> Cat: 27
# Code: 35.91 -> Cat: 27
# Code: 35.93 -> Cat: 27
# Code: 35.95 -> Cat: 27
# Code: 35.96 -> Cat: 27
# Code: 35.98 -> Cat: 27
# Code: 35.99 -> Cat: 27
# Code: 350.1 -> Cat: 5
# Code: 350.2 -> Cat: 5
# Code: 350.9 -> Cat: 5
# Code: 351.0 -> Cat: 5
# Code: 351.8 -> Cat: 5
# Code: 351.9 -> Cat: 5
# Code: 352.2 -> Cat: 5
# Code: 352.3 -> Cat: 5
# Code: 352.4 -> Cat: 5
# Code: 352.6 -> Cat: 5
# Code: 352.9 -> Cat: 5
# Code: 353.0 -> Cat: 5
# Code: 353.6 -> Cat: 5
# Code: 354.0 -> Cat: 5
# Code: 354.1 -> Cat: 5
# Code: 354.2 -> Cat: 5
# Code: 354.3 -> Cat: 5
# Code: 354.5 -> Cat: 5
# Code: 354.8 -> Cat: 5
# Code: 354.9 -> Cat: 5
# Code: 355.0 -> Cat: 5
# Code: 355.1 -> Cat: 5
# Code: 355.2 -> Cat: 5
# Code: 355.3 -> Cat: 5
# Code: 355.5 -> Cat: 5
# Code: 355.6 -> Cat: 5
# Code: 355.71 -> Cat: 5
# Code: 355.79 -> Cat: 5
# Code: 355.8 -> Cat: 5
# Code: 355.9 -> Cat: 5
# Code: 356.1 -> Cat: 5
# Code: 356.2 -> Cat: 5
# Code: 356.8 -> Cat: 5
# Code: 356.9 -> Cat: 5
# Code: 357.0 -> Cat: 5
# Code: 357.1 -> Cat: 5
# Code: 357.2 -> Cat: 5
# Code: 357.3 -> Cat: 5
# Code: 357.4 -> Cat: 5
# Code: 357.5 -> Cat: 5
# Code: 357.6 -> Cat: 5
# Code: 357.7 -> Cat: 5
# Code: 357.8 -> Cat: 5
# Code: 357.81 -> Cat: 5
# Code: 357.82 -> Cat: 5
# Code: 357.89 -> Cat: 5
# Code: 358.0 -> Cat: 5
# Code: 358.00 -> Cat: 5
# Code: 358.01 -> Cat: 5
# Code: 358.1 -> Cat: 5
# Code: 358.8 -> Cat: 5
# Code: 358.9 -> Cat: 5
# Code: 359.0 -> Cat: 5
# Code: 359.1 -> Cat: 5
# Code: 359.2 -> Cat: 5
# Code: 359.21 -> Cat: 5
# Code: 359.22 -> Cat: 5
# Code: 359.3 -> Cat: 5
# Code: 359.4 -> Cat: 5
# Code: 359.5 -> Cat: 5
# Code: 359.71 -> Cat: 5
# Code: 359.81 -> Cat: 5
# Code: 359.89 -> Cat: 5
# Code: 359.9 -> Cat: 5
# Code: 36.01 -> Cat: 27
# Code: 36.02 -> Cat: 27
# Code: 36.03 -> Cat: 27
# Code: 36.04 -> Cat: 27
# Code: 36.05 -> Cat: 27
# Code: 36.06 -> Cat: 27
# Code: 36.07 -> Cat: 27
# Code: 36.09 -> Cat: 27
# Code: 36.11 -> Cat: 27
# Code: 36.12 -> Cat: 27
# Code: 36.13 -> Cat: 27
# Code: 36.14 -> Cat: 27
# Code: 36.15 -> Cat: 27
# Code: 36.16 -> Cat: 27
# Code: 36.17 -> Cat: 27
# Code: 36.19 -> Cat: 27
# Code: 36.2 -> Cat: 27
# Code: 36.31 -> Cat: 27
# Code: 36.91 -> Cat: 27
# Code: 36.99 -> Cat: 27
# Code: 360.00 -> Cat: 5
# Code: 360.01 -> Cat: 5
# Code: 360.02 -> Cat: 5
# Code: 360.03 -> Cat: 5
# Code: 360.12 -> Cat: 5
# Code: 360.19 -> Cat: 5
# Code: 360.40 -> Cat: 5
# Code: 360.43 -> Cat: 5
# Code: 361.00 -> Cat: 5
# Code: 361.01 -> Cat: 5
# Code: 361.05 -> Cat: 5
# Code: 361.06 -> Cat: 5
# Code: 361.07 -> Cat: 5
# Code: 361.2 -> Cat: 5
# Code: 361.89 -> Cat: 5
# Code: 361.9 -> Cat: 5
# Code: 362.01 -> Cat: 5
# Code: 362.02 -> Cat: 5
# Code: 362.03 -> Cat: 5
# Code: 362.04 -> Cat: 5
# Code: 362.05 -> Cat: 5
# Code: 362.06 -> Cat: 5
# Code: 362.07 -> Cat: 5
# Code: 362.10 -> Cat: 5
# Code: 362.11 -> Cat: 5
# Code: 362.13 -> Cat: 5
# Code: 362.17 -> Cat: 5
# Code: 362.21 -> Cat: 5
# Code: 362.30 -> Cat: 5
# Code: 362.31 -> Cat: 5
# Code: 362.32 -> Cat: 5
# Code: 362.33 -> Cat: 5
# Code: 362.34 -> Cat: 5
# Code: 362.41 -> Cat: 5
# Code: 362.50 -> Cat: 5
# Code: 362.51 -> Cat: 5
# Code: 362.52 -> Cat: 5
# Code: 362.53 -> Cat: 5
# Code: 362.74 -> Cat: 5
# Code: 362.75 -> Cat: 5
# Code: 362.81 -> Cat: 5
# Code: 362.83 -> Cat: 5
# Code: 362.84 -> Cat: 5
# Code: 362.89 -> Cat: 5
# Code: 362.9 -> Cat: 5
# Code: 363.15 -> Cat: 5
# Code: 363.20 -> Cat: 5
# Code: 363.62 -> Cat: 5
# Code: 363.72 -> Cat: 5
# Code: 364.00 -> Cat: 5
# Code: 364.03 -> Cat: 5
# Code: 364.3 -> Cat: 5
# Code: 364.41 -> Cat: 5
# Code: 364.70 -> Cat: 5
# Code: 364.9 -> Cat: 5
# Code: 365.00 -> Cat: 5
# Code: 365.10 -> Cat: 5
# Code: 365.11 -> Cat: 5
# Code: 365.12 -> Cat: 5
# Code: 365.20 -> Cat: 5
# Code: 365.22 -> Cat: 5
# Code: 365.23 -> Cat: 5
# Code: 365.44 -> Cat: 5
# Code: 365.52 -> Cat: 5
# Code: 365.63 -> Cat: 5
# Code: 365.65 -> Cat: 5
# Code: 365.70 -> Cat: 5
# Code: 365.73 -> Cat: 5
# Code: 365.89 -> Cat: 5
# Code: 365.9 -> Cat: 5
# Code: 366.16 -> Cat: 5
# Code: 366.41 -> Cat: 5
# Code: 366.46 -> Cat: 5
# Code: 366.8 -> Cat: 5
# Code: 366.9 -> Cat: 5
# Code: 367.1 -> Cat: 5
# Code: 367.4 -> Cat: 5
# Code: 368.00 -> Cat: 5
# Code: 368.01 -> Cat: 5
# Code: 368.11 -> Cat: 5
# Code: 368.12 -> Cat: 5
# Code: 368.13 -> Cat: 5
# Code: 368.15 -> Cat: 5
# Code: 368.16 -> Cat: 5
# Code: 368.2 -> Cat: 5
# Code: 368.40 -> Cat: 5
# Code: 368.41 -> Cat: 5
# Code: 368.44 -> Cat: 5
# Code: 368.46 -> Cat: 5
# Code: 368.47 -> Cat: 5
# Code: 368.59 -> Cat: 5
# ...
# Code: E925.0 -> Cat: 18
# Code: E926.2 -> Cat: 18
# Code: E927 -> Cat: 18
# Code: E927.0 -> Cat: 18
# Code: E927.4 -> Cat: 18
# Code: E927.8 -> Cat: 18
# Code: E928.3 -> Cat: 18
# Code: E928.8 -> Cat: 18
# Code: E928.9 -> Cat: 18
# Code: E929.0 -> Cat: 18
# Code: E929.1 -> Cat: 18
# Code: E929.2 -> Cat: 18
# Code: E929.3 -> Cat: 18
# Code: E929.4 -> Cat: 18
# Code: E929.5 -> Cat: 18
# Code: E929.8 -> Cat: 18
# Code: E929.9 -> Cat: 18
# Code: E930.0 -> Cat: 18
# Code: E930.1 -> Cat: 18
# Code: E930.3 -> Cat: 18
# Code: E930.4 -> Cat: 18
# Code: E930.5 -> Cat: 18
# Code: E930.6 -> Cat: 18
# Code: E930.7 -> Cat: 18
# Code: E930.8 -> Cat: 18
# Code: E930.9 -> Cat: 18
# Code: E931.0 -> Cat: 18
# Code: E931.3 -> Cat: 18
# Code: E931.4 -> Cat: 18
# Code: E931.5 -> Cat: 18
# Code: E931.7 -> Cat: 18
# Code: E931.8 -> Cat: 18
# Code: E931.9 -> Cat: 18
# Code: E932.0 -> Cat: 18
# Code: E932.2 -> Cat: 18
# Code: E932.3 -> Cat: 18
# Code: E932.4 -> Cat: 18
# Code: E932.5 -> Cat: 18
# Code: E932.8 -> Cat: 18
# Code: E932.9 -> Cat: 18
# Code: E933.0 -> Cat: 18
# Code: E933.1 -> Cat: 18
# Code: E933.4 -> Cat: 18
# Code: E933.5 -> Cat: 18
# Code: E933.8 -> Cat: 18
# Code: E934.0 -> Cat: 18
# Code: E934.2 -> Cat: 18
# Code: E934.3 -> Cat: 18
# Code: E934.4 -> Cat: 18
# Code: E934.5 -> Cat: 18
# Code: E934.6 -> Cat: 18
# Code: E934.7 -> Cat: 18
# Code: E934.8 -> Cat: 18
# Code: E935.1 -> Cat: 18
# Code: E935.2 -> Cat: 18
# Code: E935.3 -> Cat: 18
# Code: E935.4 -> Cat: 18
# Code: E935.6 -> Cat: 18
# Code: E935.7 -> Cat: 18
# Code: E935.8 -> Cat: 18
# Code: E935.9 -> Cat: 18
# Code: E936.0 -> Cat: 18
# Code: E936.1 -> Cat: 18
# Code: E936.3 -> Cat: 18
# Code: E936.4 -> Cat: 18
# Code: E937.0 -> Cat: 18
# Code: E937.8 -> Cat: 18
# Code: E937.9 -> Cat: 18
# Code: E938.0 -> Cat: 18
# Code: E938.2 -> Cat: 18
# Code: E938.3 -> Cat: 18
# Code: E938.4 -> Cat: 18
# Code: E938.5 -> Cat: 18
# Code: E938.6 -> Cat: 18
# Code: E938.7 -> Cat: 18
# Code: E938.9 -> Cat: 18
# Code: E939.0 -> Cat: 18
# Code: E939.1 -> Cat: 18
# Code: E939.2 -> Cat: 18
# Code: E939.3 -> Cat: 18
# Code: E939.4 -> Cat: 18
# Code: E939.5 -> Cat: 18
# Code: E939.7 -> Cat: 18
# Code: E939.8 -> Cat: 18
# Code: E939.9 -> Cat: 18
# Code: E940.1 -> Cat: 18
# Code: E940.8 -> Cat: 18
# Code: E941.0 -> Cat: 18
# Code: E941.1 -> Cat: 18
# Code: E941.2 -> Cat: 18
# Code: E941.3 -> Cat: 18
# Code: E941.9 -> Cat: 18
# Code: E942.0 -> Cat: 18
# Code: E942.1 -> Cat: 18
# Code: E942.2 -> Cat: 18
# Code: E942.4 -> Cat: 18
# Code: E942.5 -> Cat: 18
# Code: E942.6 -> Cat: 18
# Code: E942.9 -> Cat: 18
# Code: E943.0 -> Cat: 18
# Code: E943.3 -> Cat: 18
# Code: E943.8 -> Cat: 18
# Code: E944.1 -> Cat: 18
# Code: E944.3 -> Cat: 18
# Code: E944.4 -> Cat: 18
# Code: E944.5 -> Cat: 18
# Code: E944.7 -> Cat: 18
# Code: E945.1 -> Cat: 18
# Code: E945.2 -> Cat: 18
# Code: E945.3 -> Cat: 18
# Code: E945.5 -> Cat: 18
# Code: E945.7 -> Cat: 18
# Code: E946.0 -> Cat: 18
# Code: E946.3 -> Cat: 18
# Code: E946.6 -> Cat: 18
# Code: E947.0 -> Cat: 18
# Code: E947.8 -> Cat: 18
# Code: E947.9 -> Cat: 18
# Code: E949.6 -> Cat: 18
# Code: E949.9 -> Cat: 18
# Code: E950.0 -> Cat: 18
# Code: E950.1 -> Cat: 18
# Code: E950.2 -> Cat: 18
# Code: E950.3 -> Cat: 18
# Code: E950.4 -> Cat: 18
# Code: E950.5 -> Cat: 18
# Code: E950.6 -> Cat: 18
# Code: E950.7 -> Cat: 18
# Code: E950.9 -> Cat: 18
# Code: E953.0 -> Cat: 18
# Code: E953.8 -> Cat: 18
# Code: E954 -> Cat: 18
# Code: E955.0 -> Cat: 18
# Code: E955.4 -> Cat: 18
# Code: E955.9 -> Cat: 18
# Code: E956 -> Cat: 18
# Code: E957.0 -> Cat: 18
# Code: E957.1 -> Cat: 18
# Code: E957.2 -> Cat: 18
# Code: E957.9 -> Cat: 18
# Code: E958.0 -> Cat: 18
# Code: E958.1 -> Cat: 18
# Code: E958.3 -> Cat: 18
# Code: E958.5 -> Cat: 18
# Code: E958.8 -> Cat: 18
# Code: E958.9 -> Cat: 18
# Code: E959 -> Cat: 18
# Code: E960.0 -> Cat: 18
# Code: E960.1 -> Cat: 18
# Code: E962.0 -> Cat: 18
# Code: E963 -> Cat: 18
# Code: E964 -> Cat: 18
# Code: E965.0 -> Cat: 18
# Code: E965.1 -> Cat: 18
# Code: E965.4 -> Cat: 18
# Code: E965.9 -> Cat: 18
# Code: E966 -> Cat: 18
# Code: E967.0 -> Cat: 18
# Code: E967.1 -> Cat: 18
# Code: E967.3 -> Cat: 18
# Code: E967.4 -> Cat: 18
# Code: E967.7 -> Cat: 18
# Code: E967.8 -> Cat: 18
# Code: E967.9 -> Cat: 18
# Code: E968.2 -> Cat: 18
# Code: E968.7 -> Cat: 18
# Code: E968.8 -> Cat: 18
# Code: E968.9 -> Cat: 18
# Code: E969 -> Cat: 18
# Code: E970 -> Cat: 18
# Code: E975 -> Cat: 18
# Code: E976 -> Cat: 18
# Code: E977 -> Cat: 18
# Code: E980.0 -> Cat: 18
# Code: E980.1 -> Cat: 18
# Code: E980.3 -> Cat: 18
# Code: E980.4 -> Cat: 18
# Code: E980.5 -> Cat: 18
# Code: E980.9 -> Cat: 18
# Code: E982.1 -> Cat: 18
# Code: E985.0 -> Cat: 18
# Code: E985.4 -> Cat: 18
# Code: E986 -> Cat: 18
# Code: E987.1 -> Cat: 18
# Code: E988.8 -> Cat: 18
# Code: E988.9 -> Cat: 18
# Code: E989 -> Cat: 18
# Code: E999.1 -> Cat: 18
# Code: V01.1 -> Cat: 17
# Code: V01.6 -> Cat: 17
# Code: V01.7 -> Cat: 17
# Code: V01.79 -> Cat: 17
# Code: V01.89 -> Cat: 17
# Code: V02.0 -> Cat: 17
# Code: V02.3 -> Cat: 17
# Code: V02.4 -> Cat: 17
# Code: V02.51 -> Cat: 17
# Code: V02.52 -> Cat: 17
# Code: V02.53 -> Cat: 17
# Code: V02.54 -> Cat: 17
# Code: V02.59 -> Cat: 17
# Code: V02.61 -> Cat: 17
# Code: V02.62 -> Cat: 17
# Code: V02.9 -> Cat: 17
# Code: V03.7 -> Cat: 17
# Code: V03.81 -> Cat: 17
# Code: V03.82 -> Cat: 17
# Code: V03.89 -> Cat: 17
# Code: V04.0 -> Cat: 17
# Code: V04.5 -> Cat: 17
# Code: V04.81 -> Cat: 17
# Code: V04.82 -> Cat: 17
# Code: V04.89 -> Cat: 17
# Code: V05.2 -> Cat: 17
# Code: V05.3 -> Cat: 17
# Code: V05.8 -> Cat: 17
# Code: V06.1 -> Cat: 17
# Code: V06.2 -> Cat: 17
# Code: V06.3 -> Cat: 17
# Code: V06.5 -> Cat: 17
# Code: V06.6 -> Cat: 17
# Code: V06.8 -> Cat: 17
# Code: V07.1 -> Cat: 17
# Code: V07.39 -> Cat: 17
# Code: V07.4 -> Cat: 17
# Code: V07.8 -> Cat: 17
# Code: V08 -> Cat: 17
# Code: V09.0 -> Cat: 17
# Code: V09.1 -> Cat: 17
# Code: V09.50 -> Cat: 17
# Code: V09.71 -> Cat: 17
# Code: V09.80 -> Cat: 17
# Code: V09.81 -> Cat: 17
# Code: V09.90 -> Cat: 17
# Code: V09.91 -> Cat: 17
# Code: V10.00 -> Cat: 17
# Code: V10.01 -> Cat: 17
# Code: V10.02 -> Cat: 17
# Code: V10.03 -> Cat: 17
# Code: V10.04 -> Cat: 17
# Code: V10.05 -> Cat: 17
# Code: V10.06 -> Cat: 17
# Code: V10.07 -> Cat: 17
# Code: V10.09 -> Cat: 17
# Code: V10.11 -> Cat: 17
# Code: V10.12 -> Cat: 17
# Code: V10.20 -> Cat: 17
# Code: V10.21 -> Cat: 17
# Code: V10.22 -> Cat: 17
# Code: V10.29 -> Cat: 17
# Code: V10.3 -> Cat: 17
# Code: V10.41 -> Cat: 17
# Code: V10.42 -> Cat: 17
# Code: V10.43 -> Cat: 17
# Code: V10.44 -> Cat: 17
# Code: V10.46 -> Cat: 17
# Code: V10.47 -> Cat: 17
# Code: V10.49 -> Cat: 17
# Code: V10.50 -> Cat: 17
# Code: V10.51 -> Cat: 17
# Code: V10.52 -> Cat: 17
# Code: V10.53 -> Cat: 17
# Code: V10.59 -> Cat: 17
# Code: V10.60 -> Cat: 17
# Code: V10.61 -> Cat: 17
# Code: V10.62 -> Cat: 17
# Code: V10.69 -> Cat: 17
# Code: V10.71 -> Cat: 17
# Code: V10.72 -> Cat: 17
# Code: V10.79 -> Cat: 17
# Code: V10.81 -> Cat: 17
# Code: V10.82 -> Cat: 17
# Code: V10.83 -> Cat: 17
# Code: V10.84 -> Cat: 17
# Code: V10.85 -> Cat: 17
# Code: V10.86 -> Cat: 17
# Code: V10.87 -> Cat: 17
# Code: V10.88 -> Cat: 17
# Code: V10.89 -> Cat: 17
# Code: V10.9 -> Cat: 17
# Code: V10.90 -> Cat: 17
# Code: V10.91 -> Cat: 17
# Code: V11.0 -> Cat: 17
# Code: V11.1 -> Cat: 17
# Code: V11.3 -> Cat: 17
# Code: V11.8 -> Cat: 17
# Code: V12.01 -> Cat: 17
# Code: V12.02 -> Cat: 17
# Code: V12.03 -> Cat: 17
# Code: V12.04 -> Cat: 17
# Code: V12.09 -> Cat: 17
# Code: V12.2 -> Cat: 17
# Code: V12.3 -> Cat: 17
# Code: V12.41 -> Cat: 17
# Code: V12.42 -> Cat: 17
# Code: V12.50 -> Cat: 17
# Code: V12.51 -> Cat: 17
# Code: V12.52 -> Cat: 17
# Code: V12.53 -> Cat: 17
# Code: V12.54 -> Cat: 17
# Code: V12.55 -> Cat: 17
# Code: V12.59 -> Cat: 17
# Code: V12.61 -> Cat: 17
# Code: V12.71 -> Cat: 17
# Code: V12.72 -> Cat: 17
# Code: V12.79 -> Cat: 17
# Code: V13.01 -> Cat: 17
# Code: V13.02 -> Cat: 17
# Code: V13.09 -> Cat: 17
# Code: V13.5 -> Cat: 17
# Code: V13.51 -> Cat: 17
# Code: V13.52 -> Cat: 17
# Code: V13.64 -> Cat: 17
# Code: V13.65 -> Cat: 17
# Code: V13.69 -> Cat: 17
# Code: V13.8 -> Cat: 17
# Code: V13.81 -> Cat: 17
# Code: V13.89 -> Cat: 17
# Code: V14.0 -> Cat: 17
# Code: V14.1 -> Cat: 17
# Code: V14.2 -> Cat: 17
# Code: V14.3 -> Cat: 17
# Code: V14.5 -> Cat: 17
# Code: V14.6 -> Cat: 17
# Code: V14.8 -> Cat: 17
# Code: V15.01 -> Cat: 17
# Code: V15.02 -> Cat: 17
# Code: V15.04 -> Cat: 17
# Code: V15.05 -> Cat: 17
# Code: V15.06 -> Cat: 17
# Code: V15.07 -> Cat: 17
# Code: V15.08 -> Cat: 17
# Code: V15.09 -> Cat: 17
# Code: V15.1 -> Cat: 17
# Code: V15.2 -> Cat: 17
# Code: V15.29 -> Cat: 17
# Code: V15.3 -> Cat: 17
# Code: V15.41 -> Cat: 17
# Code: V15.42 -> Cat: 17
# Code: V15.5 -> Cat: 17
# Code: V15.51 -> Cat: 17
# Code: V15.52 -> Cat: 17
# Code: V15.53 -> Cat: 17
# Code: V15.59 -> Cat: 17
# Code: V15.81 -> Cat: 17
# Code: V15.82 -> Cat: 17
# Code: V15.84 -> Cat: 17
# Code: V15.85 -> Cat: 17
# Code: V15.86 -> Cat: 17
# Code: V15.88 -> Cat: 17
# Code: V15.89 -> Cat: 17
# Code: V16.0 -> Cat: 17
# Code: V16.1 -> Cat: 17
# Code: V16.2 -> Cat: 17
# Code: V16.3 -> Cat: 17
# Code: V16.41 -> Cat: 17
# Code: V16.42 -> Cat: 17
# Code: V16.43 -> Cat: 17
# Code: V16.49 -> Cat: 17
# Code: V16.51 -> Cat: 17
# Code: V16.52 -> Cat: 17
# Code: V16.59 -> Cat: 17
# Code: V16.6 -> Cat: 17
# Code: V16.7 -> Cat: 17
# Code: V16.8 -> Cat: 17
# Code: V16.9 -> Cat: 17
# Code: V17.0 -> Cat: 17
# Code: V17.1 -> Cat: 17
# Code: V17.2 -> Cat: 17
# Code: V17.3 -> Cat: 17
# Code: V17.4 -> Cat: 17
# Code: V17.41 -> Cat: 17
# Code: V17.49 -> Cat: 17
# Code: V17.5 -> Cat: 17
# Code: V18.0 -> Cat: 17
# Code: V18.1 -> Cat: 17
# Code: V18.11 -> Cat: 17
# Code: V18.19 -> Cat: 17
# Code: V18.2 -> Cat: 17
# Code: V18.3 -> Cat: 17
# Code: V18.51 -> Cat: 17
# Code: V18.59 -> Cat: 17
# Code: V18.69 -> Cat: 17
# Code: V18.8 -> Cat: 17
# Code: V18.9 -> Cat: 17
# Code: V19.2 -> Cat: 17
# Code: V19.5 -> Cat: 17
# Code: V19.8 -> Cat: 17
# Code: V20.2 -> Cat: 17
# Code: V22.2 -> Cat: 17
# Code: V23.0 -> Cat: 17
# Code: V23.9 -> Cat: 17
# Code: V25.01 -> Cat: 17
# Code: V25.2 -> Cat: 17
# Code: V25.41 -> Cat: 17
# Code: V26.51 -> Cat: 17
# Code: V26.52 -> Cat: 17
# Code: V27.0 -> Cat: 17
# Code: V27.1 -> Cat: 17
# Code: V27.2 -> Cat: 17
# Code: V28.9 -> Cat: 17
# Code: V29.0 -> Cat: 17
# Code: V29.1 -> Cat: 17
# Code: V29.2 -> Cat: 17
# Code: V29.3 -> Cat: 17
# Code: V29.8 -> Cat: 17
# Code: V30.00 -> Cat: 17
# Code: V30.01 -> Cat: 17
# Code: V30.1 -> Cat: 17
# Code: V31.00 -> Cat: 17
# Code: V31.01 -> Cat: 17
# Code: V31.1 -> Cat: 17
# Code: V32.00 -> Cat: 17
# Code: V32.01 -> Cat: 17
# Code: V33.1 -> Cat: 17
# Code: V34.01 -> Cat: 17
# Code: V40.0 -> Cat: 17
# Code: V40.3 -> Cat: 17
# Code: V40.31 -> Cat: 17
# Code: V42.0 -> Cat: 17
# Code: V42.1 -> Cat: 17
# Code: V42.2 -> Cat: 17
# Code: V42.5 -> Cat: 17
# Code: V42.6 -> Cat: 17
# Code: V42.7 -> Cat: 17
# Code: V42.81 -> Cat: 17
# Code: V42.82 -> Cat: 17
# Code: V42.83 -> Cat: 17
# Code: V42.84 -> Cat: 17
# Code: V42.89 -> Cat: 17
# Code: V43.0 -> Cat: 17
# Code: V43.1 -> Cat: 17
# Code: V43.3 -> Cat: 17
# Code: V43.4 -> Cat: 17
# Code: V43.5 -> Cat: 17
# Code: V43.61 -> Cat: 17
# Code: V43.63 -> Cat: 17
# Code: V43.64 -> Cat: 17
# Code: V43.65 -> Cat: 17
# Code: V43.82 -> Cat: 17
# Code: V44.0 -> Cat: 17
# Code: V44.1 -> Cat: 17
# Code: V44.2 -> Cat: 17
# Code: V44.3 -> Cat: 17
# Code: V44.4 -> Cat: 17
# Code: V44.50 -> Cat: 17
# Code: V44.51 -> Cat: 17
# Code: V44.59 -> Cat: 17
# Code: V44.6 -> Cat: 17
# Code: V44.8 -> Cat: 17
# Code: V44.9 -> Cat: 17
# Code: V45.01 -> Cat: 17
# Code: V45.02 -> Cat: 17
# Code: V45.09 -> Cat: 17
# Code: V45.1 -> Cat: 17
# Code: V45.11 -> Cat: 17
# Code: V45.12 -> Cat: 17
# Code: V45.2 -> Cat: 17
# Code: V45.3 -> Cat: 17
# Code: V45.4 -> Cat: 17
# Code: V45.61 -> Cat: 17
# Code: V45.69 -> Cat: 17
# Code: V45.71 -> Cat: 17
# Code: V45.72 -> Cat: 17
# Code: V45.73 -> Cat: 17
# Code: V45.74 -> Cat: 17
# Code: V45.75 -> Cat: 17
# Code: V45.76 -> Cat: 17
# Code: V45.77 -> Cat: 17
# Code: V45.78 -> Cat: 17
# Code: V45.79 -> Cat: 17
# Code: V45.81 -> Cat: 17
# Code: V45.82 -> Cat: 17
# Code: V45.85 -> Cat: 17
# Code: V45.86 -> Cat: 17
# Code: V45.87 -> Cat: 17
# Code: V45.88 -> Cat: 17
# Code: V45.89 -> Cat: 17
# Code: V46.1 -> Cat: 17
# Code: V46.11 -> Cat: 17
# Code: V46.14 -> Cat: 17
# Code: V46.2 -> Cat: 17
# Code: V46.3 -> Cat: 17
# Code: V46.8 -> Cat: 17
# Code: V46.9 -> Cat: 17
# Code: V48.6 -> Cat: 17
# Code: V48.9 -> Cat: 17
# Code: V49.60 -> Cat: 17
# Code: V49.61 -> Cat: 17
# Code: V49.62 -> Cat: 17
# Code: V49.63 -> Cat: 17
# Code: V49.65 -> Cat: 17
# Code: V49.66 -> Cat: 17
# Code: V49.71 -> Cat: 17
# Code: V49.72 -> Cat: 17
# Code: V49.73 -> Cat: 17
# Code: V49.75 -> Cat: 17
# Code: V49.76 -> Cat: 17
# Code: V49.81 -> Cat: 17
# Code: V49.83 -> Cat: 17
# Code: V49.84 -> Cat: 17
# Code: V49.85 -> Cat: 17
# Code: V49.86 -> Cat: 17
# Code: V49.87 -> Cat: 17
# Code: V49.89 -> Cat: 17
# Code: V50.2 -> Cat: 17
# Code: V50.3 -> Cat: 17
# Code: V50.41 -> Cat: 17
# Code: V50.49 -> Cat: 17
# Code: V51 -> Cat: 17
# Code: V51.0 -> Cat: 17
# Code: V53.01 -> Cat: 17
# Code: V53.02 -> Cat: 17
# Code: V53.09 -> Cat: 17
# Code: V53.31 -> Cat: 17
# Code: V53.32 -> Cat: 17
# Code: V53.39 -> Cat: 17
# Code: V53.6 -> Cat: 17
# Code: V53.7 -> Cat: 17
# Code: V53.91 -> Cat: 17
# Code: V53.99 -> Cat: 17
# Code: V54.01 -> Cat: 17
# Code: V54.10 -> Cat: 17
# Code: V54.11 -> Cat: 17
# Code: V54.12 -> Cat: 17
# Code: V54.13 -> Cat: 17
# Code: V54.15 -> Cat: 17
# Code: V54.16 -> Cat: 17
# Code: V54.17 -> Cat: 17
# Code: V54.19 -> Cat: 17
# Code: V54.22 -> Cat: 17
# Code: V54.23 -> Cat: 17
# Code: V54.26 -> Cat: 17
# Code: V54.27 -> Cat: 17
# Code: V54.81 -> Cat: 17
# Code: V54.82 -> Cat: 17
# Code: V54.89 -> Cat: 17
# Code: V54.9 -> Cat: 17
# Code: V55.0 -> Cat: 17
# Code: V55.1 -> Cat: 17
# Code: V55.2 -> Cat: 17
# Code: V55.3 -> Cat: 17
# Code: V55.4 -> Cat: 17
# Code: V55.5 -> Cat: 17
# Code: V55.6 -> Cat: 17
# Code: V55.8 -> Cat: 17
# Code: V56.0 -> Cat: 17
# Code: V56.1 -> Cat: 17
# Code: V56.8 -> Cat: 17
# Code: V58.0 -> Cat: 17
# Code: V58.1 -> Cat: 17
# Code: V58.11 -> Cat: 17
# Code: V58.12 -> Cat: 17
# Code: V58.3 -> Cat: 17
# Code: V58.31 -> Cat: 17
# Code: V58.41 -> Cat: 17
# Code: V58.42 -> Cat: 17
# Code: V58.43 -> Cat: 17
# Code: V58.44 -> Cat: 17
# Code: V58.49 -> Cat: 17
# Code: V58.61 -> Cat: 17
# Code: V58.62 -> Cat: 17
# Code: V58.63 -> Cat: 17
# Code: V58.64 -> Cat: 17
# Code: V58.65 -> Cat: 17
# Code: V58.66 -> Cat: 17
# Code: V58.67 -> Cat: 17
# Code: V58.69 -> Cat: 17
# Code: V58.73 -> Cat: 17
# Code: V58.81 -> Cat: 17
# Code: V58.83 -> Cat: 17
# Code: V59.6 -> Cat: 17
# Code: V60.0 -> Cat: 17
# Code: V60.1 -> Cat: 17
# Code: V60.2 -> Cat: 17
# Code: V60.4 -> Cat: 17
# Code: V60.8 -> Cat: 17
# Code: V61.0 -> Cat: 17
# Code: V61.03 -> Cat: 17
# Code: V61.04 -> Cat: 17
# Code: V61.07 -> Cat: 17
# Code: V61.09 -> Cat: 17
# Code: V61.10 -> Cat: 17
# Code: V61.11 -> Cat: 17
# Code: V61.29 -> Cat: 17
# Code: V61.41 -> Cat: 17
# Code: V61.42 -> Cat: 17
# Code: V61.49 -> Cat: 17
# Code: V61.8 -> Cat: 17
# Code: V62.0 -> Cat: 17
# Code: V62.4 -> Cat: 17
# Code: V62.5 -> Cat: 17
# Code: V62.6 -> Cat: 17
# Code: V62.82 -> Cat: 17
# Code: V62.84 -> Cat: 17
# Code: V62.85 -> Cat: 17
# Code: V62.89 -> Cat: 17
# Code: V63.2 -> Cat: 17
# Code: V63.8 -> Cat: 17
# Code: V64.0 -> Cat: 17
# Code: V64.05 -> Cat: 17
# Code: V64.06 -> Cat: 17
# Code: V64.1 -> Cat: 17
# Code: V64.2 -> Cat: 17
# Code: V64.3 -> Cat: 17
# Code: V64.4 -> Cat: 17
# Code: V64.41 -> Cat: 17
# Code: V64.42 -> Cat: 17
# Code: V64.43 -> Cat: 17
# Code: V65.2 -> Cat: 17
# Code: V65.3 -> Cat: 17
# Code: V65.42 -> Cat: 17
# Code: V65.49 -> Cat: 17
# Code: V65.5 -> Cat: 17
# Code: V66.0 -> Cat: 17
# Code: V66.7 -> Cat: 17
# Code: V67.1 -> Cat: 17
# Code: V67.2 -> Cat: 17
# Code: V69.4 -> Cat: 17
# Code: V69.8 -> Cat: 17
# Code: V70.3 -> Cat: 17
# Code: V70.7 -> Cat: 17
# Code: V70.8 -> Cat: 17
# Code: V71.4 -> Cat: 17
# Code: V71.6 -> Cat: 17
# Code: V72.1 -> Cat: 17
# Code: V72.19 -> Cat: 17
# Code: V72.81 -> Cat: 17
# Code: V74.1 -> Cat: 17
# Code: V76.51 -> Cat: 17
# Code: V78.9 -> Cat: 17
# Code: V81.2 -> Cat: 17
# Code: V83.81 -> Cat: 17
# Code: V83.89 -> Cat: 17
# Code: V84.01 -> Cat: 17
# Code: V84.09 -> Cat: 17
# Code: V84.89 -> Cat: 17
# Code: V85.0 -> Cat: 17
# Code: V85.1 -> Cat: 17
# Code: V85.21 -> Cat: 17
# Code: V85.22 -> Cat: 17
# Code: V85.23 -> Cat: 17
# Code: V85.24 -> Cat: 17
# Code: V85.25 -> Cat: 17
# Code: V85.30 -> Cat: 17
# Code: V85.31 -> Cat: 17
# Code: V85.32 -> Cat: 17
# Code: V85.33 -> Cat: 17
# Code: V85.34 -> Cat: 17
# Code: V85.35 -> Cat: 17
# Code: V85.36 -> Cat: 17
# Code: V85.37 -> Cat: 17
# Code: V85.38 -> Cat: 17
# Code: V85.39 -> Cat: 17
# Code: V85.4 -> Cat: 17
# Code: V85.41 -> Cat: 17
# Code: V85.42 -> Cat: 17
# Code: V85.43 -> Cat: 17
# Code: V85.44 -> Cat: 17
# Code: V85.45 -> Cat: 17
# Code: V86.0 -> Cat: 17
# Code: V86.1 -> Cat: 17
# Code: V87.09 -> Cat: 17
# Code: V87.2 -> Cat: 17
# Code: V87.41 -> Cat: 17
# Code: V87.45 -> Cat: 17
# Code: V88.01 -> Cat: 17
# Code: V88.11 -> Cat: 17
# Code: V88.12 -> Cat: 17
# Code: V88.21 -> Cat: 17
# Code: V90.10 -> Cat: 17
# Code: V90.39 -> Cat: 17
# Code: V90.81 -> Cat: 17
# Code: V90.89 -> Cat: 17
# Code: V91.03 -> Cat: 17

# %%
with open(os.path.join(root, 'data', 'processed', 'data_MimicFull', 'code_embeddings', f'embedding_matrix_MimicFull_mapping.pkl'), 'wb') as f:
    pickle.dump(cat2label_mapping_full, f)

# %% [markdown]
# ## MIMIC-III-50

# %%
# Retain all categories associated with MIMIC-III-50:
dict_cat_desc_50 = {
    '001-139': 'Infectious And Parasitic Diseases',
    '240-279': 'Endocrine, Nutritional And Metabolic Diseases, And Immunity Disorders',
    '280-289': 'Diseases Of The Blood And Blood-Forming Organs',
    '290-319': 'Mental Disorders',
    '390-459': 'Diseases Of The Circulatory System',
    '460-519': 'Diseases Of The Respiratory System',
    '520-579': 'Diseases Of The Digestive System',
    '580-629': 'Diseases Of The Genitourinary System',
    '800-999': 'Injury And Poisoning',
    'V01-V91': 'Supplementary Classification Of Factors Influencing Health Status And Contact With Health Services',
    '30-34': 'Operations On The Respiratory System',
    '35-39': 'Operations On The Cardiovascular System',
    '42-54': 'Operations On The Digestive System',
    '87-99': 'Miscellaneous Diagnostic And Therapeutic Procedures'
}

# Create a pandas dataframe
df_cat_desc_50 = pd.DataFrame.from_dict(data=dict_cat_desc_50.items())
df_cat_desc_50.columns = ['categories', 'description']
df_cat_desc_50
# Out:
#    categories                                        description
# 0     001-139                  Infectious And Parasitic Diseases
# 1     240-279  Endocrine, Nutritional And Metabolic Diseases,...
# 2     280-289     Diseases Of The Blood And Blood-Forming Organs
# 3     290-319                                   Mental Disorders
# 4     390-459                 Diseases Of The Circulatory System
# 5     460-519                 Diseases Of The Respiratory System
# 6     520-579                   Diseases Of The Digestive System
# 7     580-629               Diseases Of The Genitourinary System
# 8     800-999                               Injury And Poisoning
# 9     V01-V91  Supplementary Classification Of Factors Influe...
# 10      30-34               Operations On The Respiratory System
# 11      35-39            Operations On The Cardiovascular System
# 12      42-54                 Operations On The Digestive System
# 13      87-99  Miscellaneous Diagnostic And Therapeutic Proce...

# %%
df_cat_desc_50['desc_clean'] = df_cat_desc_50.apply(lambda x: clean_desc(text=x.description), axis=1)
display(df_cat_desc_50)


docs = df_cat_desc_50['desc_clean'].tolist()  # corpus to learn code descriptions - one doc is one label description
tags = df_cat_desc_50['categories'].tolist()  # assign labels as tags
# Out:
#    categories                                        description  \
# 0     001-139                  Infectious And Parasitic Diseases
# 1     240-279  Endocrine, Nutritional And Metabolic Diseases,...
# 2     280-289     Diseases Of The Blood And Blood-Forming Organs
# 3     290-319                                   Mental Disorders
# 4     390-459                 Diseases Of The Circulatory System
# 5     460-519                 Diseases Of The Respiratory System
# 6     520-579                   Diseases Of The Digestive System
# 7     580-629               Diseases Of The Genitourinary System
# 8     800-999                               Injury And Poisoning
# 9     V01-V91  Supplementary Classification Of Factors Influe...
# 10      30-34               Operations On The Respiratory System
# 11      35-39            Operations On The Cardiovascular System
# 12      42-54                 Operations On The Digestive System
# 13      87-99  Miscellaneous Diagnostic And Therapeutic Proce...
#
#                                            desc_clean
# 0                   [infectious, parasitic, diseases]
# 1   [endocrine, nutritional, metabolic, diseases, ...
# 2             [diseases, blood, bloodforming, organs]
# 3                                 [mental, disorders]
# 4                     [diseases, circulatory, system]
# 5                     [diseases, respiratory, system]
# 6                       [diseases, digestive, system]
# 7                   [diseases, genitourinary, system]
# 8                                 [injury, poisoning]
# 9   [supplementary, classification, factors, influ...
# 10                  [operations, respiratory, system]
# 11               [operations, cardiovascular, system]
# 12                    [operations, digestive, system]
# 13  [miscellaneous, diagnostic, therapeutic, proce...

# %%
# Compute pre-trained word embeddings for embedding layer using Word2Vec
documents = [TaggedDocument(doc, [tag]) for doc, tag in zip(docs, tags)]
embedding_dims = [100, 200, 300]
for dim in embedding_dims:
    print()
    print(f'Create word embedding matrices with dimenions: {dim}')
    model = Doc2Vec(documents, vector_size=dim, window=2, min_count=1, workers=4)
    model_shape = model.dv.vectors.shape
    print('Shape of document embedding matrix.')
    print(f'Number of sentence embeddings: {model_shape[0]}')
    print(f'Word embedding dimension: {model_shape[1]}')
    
    print()
    print('Create label embedding matrix for Mimic50:')
    label_embedding_matrix = model.dv.vectors
    with open(os.path.join(root, 'data', 'processed', 'data_Mimic50', 'code_embeddings', f'cat_embedding_matrix_Mimic50_{dim}.pkl'), 'wb') as f:
        pickle.dump(label_embedding_matrix, f)
# Out:
# Create word embedding matrices with dimenions: 100
# Shape of document embedding matrix.
# Number of sentence embeddings: 14
# Word embedding dimension: 100
#
# Create label embedding matrix for Mimic50:
#
# Create word embedding matrices with dimenions: 200
# Shape of document embedding matrix.
# Number of sentence embeddings: 14
# Word embedding dimension: 200
#
# Create label embedding matrix for Mimic50:
#
# Create word embedding matrices with dimenions: 300
# Shape of document embedding matrix.
# Number of sentence embeddings: 14
# Word embedding dimension: 300
#
# Create label embedding matrix for Mimic50:

# %% [markdown]
# ### Retrieve Category to billable Code Mapping

# %%
df_cat_50 = pd.DataFrame.from_dict(data=dict_cat_desc_50.items())
df_cat_50.columns = ['categories', 'description']

cat_bounds_50 = df_cat_50['categories'].str.split("-", n = 1, expand = True)
df_cat_50['cat_lower'] = cat_bounds_50[0]
df_cat_50['cat_upper'] = cat_bounds_50[1]

lower_bounds_50 = list(cat_bounds_50[0])
upper_bounds_50 = list(cat_bounds_50[1])

# %%
cat2label_mapping_50 = []
for label in labels_50:
    for i, (lower, upper) in enumerate(zip(lower_bounds_50, upper_bounds_50)):
        if '.' in label:
            if label[2] == '.':  # procedure code
                if len(lower) == 2:
                    if lower <= label[:2] <= upper:
                        print(f'Code: {label} -> Cat: {i}')
                        cat2label_mapping_50.append(i)
            else:  # diagnosis code
                if len(lower) == 3:
                    if lower <= label[:3] <= upper:
                        print(f'Code: {label} -> Cat: {i}')
                        cat2label_mapping_50.append(i)
                elif len(lower) == 4:  # codes starting with 'E'
                    if lower <= label[:4] <= upper:
                        print(f'Code: {label} -> Cat: {i}')
                        cat2label_mapping_50.append(i)
        else:
            if len(label) == 2:
                if len(lower) == 2:
                    if lower <= label <= upper:
                        print(f'Code: {label} -> Cat: {i}')
                        cat2label_mapping_50.append(i)
            elif len(label) == 3:
                if len(lower) == 3:
                    if lower <= label <= upper:
                        print(f'Code: {label} -> Cat: {i}')
                        cat2label_mapping_50.append(i)
            elif len(label) == 4:
                if len(lower) == 4:
                    if lower <= label <= upper:
                        print(f'Code: {label} -> Cat: {i}')
                        cat2label_mapping_50.append(i)
# Out:
# Code: 038.9 -> Cat: 0
# Code: 244.9 -> Cat: 1
# Code: 250.00 -> Cat: 1
# Code: 272.0 -> Cat: 1
# Code: 272.4 -> Cat: 1
# Code: 276.1 -> Cat: 1
# Code: 276.2 -> Cat: 1
# Code: 285.1 -> Cat: 2
# Code: 285.9 -> Cat: 2
# Code: 287.5 -> Cat: 2
# Code: 305.1 -> Cat: 3
# Code: 311 -> Cat: 3
# Code: 33.24 -> Cat: 10
# Code: 36.15 -> Cat: 11
# Code: 37.22 -> Cat: 11
# Code: 38.91 -> Cat: 11
# Code: 38.93 -> Cat: 11
# Code: 39.61 -> Cat: 11
# Code: 39.95 -> Cat: 11
# Code: 401.9 -> Cat: 4
# Code: 403.90 -> Cat: 4
# Code: 410.71 -> Cat: 4
# Code: 412 -> Cat: 4
# Code: 414.01 -> Cat: 4
# Code: 424.0 -> Cat: 4
# Code: 427.31 -> Cat: 4
# Code: 428.0 -> Cat: 4
# Code: 45.13 -> Cat: 12
# Code: 486 -> Cat: 5
# Code: 496 -> Cat: 5
# Code: 507.0 -> Cat: 5
# Code: 511.9 -> Cat: 5
# Code: 518.81 -> Cat: 5
# Code: 530.81 -> Cat: 6
# Code: 584.9 -> Cat: 7
# Code: 585.9 -> Cat: 7
# Code: 599.0 -> Cat: 7
# Code: 88.56 -> Cat: 13
# Code: 88.72 -> Cat: 13
# Code: 93.90 -> Cat: 13
# Code: 96.04 -> Cat: 13
# Code: 96.6 -> Cat: 13
# Code: 96.71 -> Cat: 13
# Code: 96.72 -> Cat: 13
# Code: 99.04 -> Cat: 13
# Code: 99.15 -> Cat: 13
# Code: 995.92 -> Cat: 8
# Code: V15.82 -> Cat: 9
# Code: V45.81 -> Cat: 9
# Code: V58.61 -> Cat: 9

# %%
with open(os.path.join(root, 'data', 'processed', 'data_Mimic50', 'code_embeddings', f'embedding_matrix_Mimic50_mapping.pkl'), 'wb') as f:
    pickle.dump(cat2label_mapping_50, f)
